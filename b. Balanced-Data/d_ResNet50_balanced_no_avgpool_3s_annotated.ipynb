# %% [markdown]
# # **Convolutional Neural Network**
# **Starting parameters**:
#
# - Number of epochs: 100
# - Learning rate: 0.0005
# - Layers: [64, 32, 32]
# - Dropout: 0.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard libraries
import numpy as np
import pandas as pd
import time
import os

# For preprocessing
import tensorflow as tf

# For modeling
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_auc_score, f1_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import VGG16

# Operational
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import time
import random

# %%
pkl_path = '/content/drive/My Drive/Final-Year-Project/Dataset/Final-Version-of-Bird-Classification-Project/feature-extraction/Annotated/Augmented/NotAveragePooled/split_features_3s_all_2D.pkl'

# Load the pickle file
with open(pkl_path, 'rb') as file:
    data = pickle.load(file)
del file

# %%
path = '/content/drive/My Drive/Final-Year-Project/Final-Version-of-Bird-Classification-Project/Final-Version-of-Bird-Classification-Project/b. Balanced-Data/Figures/'

# %%
train_data = data['train'].copy()
val_data = data['val'].copy()
del data

train_labels = train_data['label'].copy()
temp = train_data.copy()
del temp['label']
tr_features = temp

val_labels = val_data['label'].copy()
temp = val_data.copy()
del temp['label']
v_features = temp

# %% [markdown]
# ## **Shuffling Data**

# %%
def shuffle_data(input_label, input_features):
  input_len = len(input_label)
  np.random.seed(1826)
  input_indices = np.random.permutation(input_len)
  input_features = {key: np.array([input_features[key][i] for i in input_indices]) for key in input_features} # dictionary comprehension
  input_label = np.array([input_label[i] for i in input_indices])

  return input_label, input_features

# %%
train_y, train_features = shuffle_data(train_labels, tr_features)

# %%
val_y, val_features = shuffle_data(val_labels, v_features)

# %% [markdown]
# ## **CNN Model**

# %%
from tensorflow.keras.applications import ResNet50

def build_efficientnet_model(audio_features, learning_rate=0.00005, num_classes=20):
    tf.keras.backend.clear_session()

    # Load EfficientNetB0 with ImageNet weights, excluding the top layer
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(audio_features.shape[1], audio_features.shape[2], audio_features.shape[3]))

    # Unfreeze last few layers for fine-tuning
    for layer in base_model.layers[-10:]:
        layer.trainable = True

    # Input layer for the audio features
    inputs = tf.keras.layers.Input(shape=(audio_features.shape[1], audio_features.shape[2], audio_features.shape[3]), name='Audio_Features')

    # Extract features using the base model
    features = base_model(inputs)

    # Add a global average pooling layer
    features = tf.keras.layers.GlobalAveragePooling2D()(features)

    # Add Batch Normalization
    features = tf.keras.layers.BatchNormalization()(features)

    # Add a custom fully connected (dense) layer
    features = tf.keras.layers.Dense(
        units=128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.00015),
        name='fc_1')(features)

    # Add dropout layer for regularization
    features = tf.keras.layers.Dropout(rate=0.4)(features)

    features = tf.keras.layers.Dense(
        units=64,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.00015),
        name='fc_2')(features)

    # Add Batch Normalization
    features = tf.keras.layers.BatchNormalization()(features)

    features = tf.keras.layers.Dropout(rate=0.4)(features)

    # Output layer with softmax activation
    outputs = tf.keras.layers.Dense(
        units=num_classes,
        activation='softmax',
        name='fc_output')(features)

    # Build the model
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name='EfficientNetB0_Audio_Classification')

    print(model.summary())

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

    return model

# %%
def visualize(model_history, name):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Visualize the loss
    axes[0].plot(model_history.history['loss'], color='red', label='Training Loss')
    axes[0].plot(model_history.history['val_loss'], color='blue', label='Validation Loss')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss Progression', fontsize=14)
    axes[0].grid(True)
    axes[0].legend()

    # Visualize the accuracy
    axes[1].plot(model_history.history['accuracy'], color='green', label='Training Accuracy')
    axes[1].plot(model_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Accuracy Progression', fontsize=14)
    axes[1].grid(True)
    axes[1].legend()

    plt.savefig(f'{path+name}_3s_model_training_history_2D_annotated_ResNet50.pdf')

    # Fine-tune layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
def evaluate_model(val_y, val_yhat, val_yhat_result, num_classes=20):

    print('Validation classification Report \n')
    print(classification_report(val_y, val_yhat_result))

    # Calculate AUC for multiclass classification using 'ovr' and 'weighted' average
    auc_score = roc_auc_score(val_y, val_yhat, multi_class='ovr', average='weighted')
    print(f'AUC Score: {auc_score}')

    # Calculate F1-score with 'weighted' average for imbalanced dataset
    f1 = f1_score(val_y, val_yhat_result, average='weighted')
    print(f'F1 Score (Weighted): {f1}')

    val_score = {'f1': f1, 'auc': auc_score}

    return val_score

# %%
def tile_and_crop(feature, target_size):
    tiled = np.tile(feature, (1, target_size // feature.shape[1] + 1, 1))
    return tiled[:, :target_size, :]

# %%
train_results = {}
val_results = {}

val_scores = {}

# %% [markdown]
# ### With Mel Spectrogram, MFCCs and Chroma

# %%
# Validation Features
target_size = 128
mfcc_tiled = tile_and_crop(val_features['mfcc'], target_size)
chroma_tiled = tile_and_crop(val_features['chroma'], target_size)

validation_features = np.stack((val_features['melspectrogram'], mfcc_tiled, chroma_tiled), axis=-1)
print(validation_features.shape)
# Out:
# (1350, 128, 259, 3)

# %%
# Train features
target_size = 128
mfcc_tiled = tile_and_crop(train_features['mfcc'], target_size)
chroma_tiled = tile_and_crop(train_features['chroma'], target_size)

training_features = np.stack((train_features['melspectrogram'], mfcc_tiled, chroma_tiled), axis=-1)
print(training_features.shape)
# Out:
# (9197, 128, 259, 3)

# %%
model = build_efficientnet_model(training_features)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=60,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1
)
# Out:
# Model: "EfficientNetB0_Audio_Classification"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Audio_Features (InputLayer)          │ (None, 128, 259, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 4, 9, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc_1 (Dense)                         │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc_2 (Dense)                         │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc_output (Dense)                    │ (None, 20)                  │           1,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,867,988 (91.05 MB)
#  Trainable params: 23,810,644 (90.83 MB)
#  Non-trainable params: 57,344 (224.00 KB)
# None
# Epoch 1/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 150s 341ms/step - accuracy: 0.2367 - loss: 2.8931 - val_accuracy: 0.0400 - val_loss: 74.7778
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 220ms/step - accuracy: 0.6553 - loss: 1.3292 - val_accuracy: 0.0289 - val_loss: 39.8678
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 62s 217ms/step - accuracy: 0.8094 - loss: 0.8510 - val_accuracy: 0.1696 - val_loss: 3.2187
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.8797 - loss: 0.6167 - val_accuracy: 0.4541 - val_loss: 2.1379
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9163 - loss: 0.4773 - val_accuracy: 0.7578 - val_loss: 1.0754
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9444 - loss: 0.3804 - val_accuracy: 0.7615 - val_loss: 1.1150
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9559 - loss: 0.3294 - val_accuracy: 0.7807 - val_loss: 1.0042
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9713 - loss: 0.2648 - val_accuracy: 0.7756 - val_loss: 1.0590
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9833 - loss: 0.2126 - val_accuracy: 0.7919 - val_loss: 0.9499
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9785 - loss: 0.2147 - val_accuracy: 0.7948 - val_loss: 0.8788
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9791 - loss: 0.1970 - val_accuracy: 0.7622 - val_loss: 1.1656
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9795 - loss: 0.1968 - val_accuracy: 0.7859 - val_loss: 1.0884
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9807 - loss: 0.1832 - val_accuracy: 0.8148 - val_loss: 0.8881
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9845 - loss: 0.1629 - val_accuracy: 0.7985 - val_loss: 1.0322
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9859 - loss: 0.1544 - val_accuracy: 0.7593 - val_loss: 1.1831
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9816 - loss: 0.1615 - val_accuracy: 0.7948 - val_loss: 1.0441
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9867 - loss: 0.1497 - val_accuracy: 0.7970 - val_loss: 1.0408
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 62s 217ms/step - accuracy: 0.9891 - loss: 0.1358 - val_accuracy: 0.7963 - val_loss: 1.0617
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9938 - loss: 0.1074 - val_accuracy: 0.7585 - val_loss: 1.3037
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9941 - loss: 0.1034 - val_accuracy: 0.7881 - val_loss: 1.1326
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9933 - loss: 0.1019 - val_accuracy: 0.7430 - val_loss: 1.4837
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9836 - loss: 0.1364 - val_accuracy: 0.7941 - val_loss: 1.1218
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9848 - loss: 0.1412 - val_accuracy: 0.7993 - val_loss: 1.0675
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9908 - loss: 0.1083 - val_accuracy: 0.8185 - val_loss: 1.0669
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9928 - loss: 0.1004 - val_accuracy: 0.8081 - val_loss: 1.1977
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9938 - loss: 0.0915 - val_accuracy: 0.7793 - val_loss: 1.2509
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9889 - loss: 0.1104 - val_accuracy: 0.7978 - val_loss: 1.1307
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9886 - loss: 0.1144 - val_accuracy: 0.7978 - val_loss: 1.0437
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9929 - loss: 0.0944 - val_accuracy: 0.7659 - val_loss: 1.3524
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9921 - loss: 0.0957 - val_accuracy: 0.7948 - val_loss: 1.2040
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9961 - loss: 0.0768 - val_accuracy: 0.8222 - val_loss: 1.0646
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9990 - loss: 0.0639 - val_accuracy: 0.7852 - val_loss: 1.2712
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9976 - loss: 0.0702 - val_accuracy: 0.7933 - val_loss: 1.3124
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9952 - loss: 0.0791 - val_accuracy: 0.7763 - val_loss: 1.3622
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9879 - loss: 0.1053 - val_accuracy: 0.7630 - val_loss: 1.4639
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9911 - loss: 0.0949 - val_accuracy: 0.7793 - val_loss: 1.2713
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9921 - loss: 0.0855 - val_accuracy: 0.8133 - val_loss: 1.1569
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9928 - loss: 0.0842 - val_accuracy: 0.7896 - val_loss: 1.1915
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9927 - loss: 0.0834 - val_accuracy: 0.8141 - val_loss: 1.0939
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9968 - loss: 0.0667 - val_accuracy: 0.7993 - val_loss: 1.2205
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9983 - loss: 0.0591 - val_accuracy: 0.7378 - val_loss: 1.5011
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9921 - loss: 0.0881 - val_accuracy: 0.8111 - val_loss: 1.2363
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9962 - loss: 0.0659 - val_accuracy: 0.7933 - val_loss: 1.2147
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9918 - loss: 0.0852 - val_accuracy: 0.7874 - val_loss: 1.3083
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9911 - loss: 0.0969 - val_accuracy: 0.8022 - val_loss: 1.2204
# Epoch 46/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9907 - loss: 0.0826 - val_accuracy: 0.8104 - val_loss: 1.1623
# Epoch 47/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9951 - loss: 0.0712 - val_accuracy: 0.7785 - val_loss: 1.4382
# Epoch 48/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 62s 217ms/step - accuracy: 0.9962 - loss: 0.0625 - val_accuracy: 0.7978 - val_loss: 1.3446
# Epoch 49/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9957 - loss: 0.0638 - val_accuracy: 0.8133 - val_loss: 1.1845
# Epoch 50/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9947 - loss: 0.0681 - val_accuracy: 0.8133 - val_loss: 1.1744
# Epoch 51/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9932 - loss: 0.0791 - val_accuracy: 0.8081 - val_loss: 1.1805
# Epoch 52/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9973 - loss: 0.0564 - val_accuracy: 0.7830 - val_loss: 1.2910
# Epoch 53/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9963 - loss: 0.0640 - val_accuracy: 0.7748 - val_loss: 1.4090
# Epoch 54/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9978 - loss: 0.0538 - val_accuracy: 0.8215 - val_loss: 1.1767
# Epoch 55/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9952 - loss: 0.0660 - val_accuracy: 0.8319 - val_loss: 1.0579
# Epoch 56/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9951 - loss: 0.0684 - val_accuracy: 0.7867 - val_loss: 1.3915
# Epoch 57/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9988 - loss: 0.0489 - val_accuracy: 0.8319 - val_loss: 1.2052
# Epoch 58/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9987 - loss: 0.0485 - val_accuracy: 0.8289 - val_loss: 1.1262
# Epoch 59/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9984 - loss: 0.0493 - val_accuracy: 0.8052 - val_loss: 1.2808
# Epoch 60/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9972 - loss: 0.0488 - val_accuracy: 0.8207 - val_loss: 1.1883

# %%
model.save('/content/drive/My Drive/Final-Year-Project/Dataset/Final-Version-of-Bird-Classification-Project/ML Models/Transfer Learning/ResNet50_melspectrogram_chroma_mfcc_balanced.keras')

# %%
visualize(history, 'melspectrogram_chroma_mfcc')

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['melspectrogram_chroma_mfcc'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['melspectrogram_chroma_mfcc'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 23s 69ms/step
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - accuracy: 0.9997 - loss: 0.0374
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8290 - loss: 1.0999

# %%
val_scores['melspectrogram_chroma_mfcc'] = evaluate_model(val_y=val_y, val_yhat=val_yhat, val_yhat_result=val_yhat_result)
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       114
#            1       0.63      0.77      0.69       141
#            2       0.88      0.75      0.81       271
#            3       0.95      1.00      0.97        90
#            4       0.50      0.17      0.25        18
#            5       0.62      0.87      0.72        15
#            6       0.52      0.61      0.56        23
#            7       0.98      1.00      0.99        44
#            8       0.78      0.70      0.74        50
#            9       0.92      0.94      0.93        49
#           10       0.94      0.98      0.96        48
#           11       0.84      0.59      0.69        46
#           12       0.95      1.00      0.97        54
#           13       0.52      0.75      0.62        48
#           14       0.58      0.92      0.71        38
#           15       0.81      0.62      0.71       117
#           16       1.00      0.95      0.97        55
#           17       1.00      0.94      0.97        69
#           18       0.65      0.90      0.75        29
#           19       0.88      0.90      0.89        31
#
#     accuracy                           0.82      1350
#    macro avg       0.80      0.82      0.79      1350
# weighted avg       0.84      0.82      0.82      1350
#
# AUC Score: 0.9720508310793693
# F1 Score (Weighted): 0.8207670838289259

# %% [markdown]
# ### With Mel Spectrogram and MFCCs and CQT

# %%
# Train features
target_size = 128
mfcc_tiled = tile_and_crop(train_features['mfcc'], target_size)
cqt_tiled = tile_and_crop(train_features['cqt'], target_size)

training_features = np.stack((train_features['melspectrogram'], mfcc_tiled, cqt_tiled), axis=-1)
print(training_features.shape)
# Out:
# (9197, 128, 259, 3)

# %%
# Validation Features
target_size = 128
mfcc_tiled = tile_and_crop(val_features['mfcc'], target_size)
cqt_tiled = tile_and_crop(val_features['cqt'], target_size)

validation_features = np.stack((val_features['melspectrogram'], mfcc_tiled, cqt_tiled), axis=-1)
print(validation_features.shape)
# Out:
# (1350, 128, 259, 3)

# %%
model = build_efficientnet_model(training_features)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=60,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1
)
# Out:
# Model: "EfficientNetB0_Audio_Classification"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Audio_Features (InputLayer)          │ (None, 128, 259, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 4, 9, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc_1 (Dense)                         │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc_2 (Dense)                         │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc_output (Dense)                    │ (None, 20)                  │           1,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,867,988 (91.05 MB)
#  Trainable params: 23,810,644 (90.83 MB)
#  Non-trainable params: 57,344 (224.00 KB)
# None
# Epoch 1/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 148s 318ms/step - accuracy: 0.2732 - loss: 2.8011 - val_accuracy: 0.2815 - val_loss: 2.6616
# Epoch 2/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 219ms/step - accuracy: 0.6718 - loss: 1.2425 - val_accuracy: 0.7200 - val_loss: 1.1554
# Epoch 3/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 62s 217ms/step - accuracy: 0.8336 - loss: 0.7351 - val_accuracy: 0.7200 - val_loss: 1.0921
# Epoch 4/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9089 - loss: 0.5174 - val_accuracy: 0.7704 - val_loss: 0.9199
# Epoch 5/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9450 - loss: 0.3814 - val_accuracy: 0.7504 - val_loss: 1.0079
# Epoch 6/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9635 - loss: 0.3073 - val_accuracy: 0.7674 - val_loss: 1.0300
# Epoch 7/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9749 - loss: 0.2415 - val_accuracy: 0.7444 - val_loss: 1.1030
# Epoch 8/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9788 - loss: 0.2301 - val_accuracy: 0.7667 - val_loss: 1.0511
# Epoch 9/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9759 - loss: 0.2125 - val_accuracy: 0.7830 - val_loss: 0.9876
# Epoch 10/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9870 - loss: 0.1732 - val_accuracy: 0.7689 - val_loss: 1.1131
# Epoch 11/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9857 - loss: 0.1675 - val_accuracy: 0.8037 - val_loss: 0.9874
# Epoch 12/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9900 - loss: 0.1483 - val_accuracy: 0.7933 - val_loss: 1.0401
# Epoch 13/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9832 - loss: 0.1733 - val_accuracy: 0.7600 - val_loss: 1.1789
# Epoch 14/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9870 - loss: 0.1461 - val_accuracy: 0.7585 - val_loss: 1.2354
# Epoch 15/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9870 - loss: 0.1436 - val_accuracy: 0.7911 - val_loss: 1.0563
# Epoch 16/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9886 - loss: 0.1316 - val_accuracy: 0.7867 - val_loss: 1.1228
# Epoch 17/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9911 - loss: 0.1220 - val_accuracy: 0.7563 - val_loss: 1.2653
# Epoch 18/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9923 - loss: 0.1120 - val_accuracy: 0.7422 - val_loss: 1.3543
# Epoch 19/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9886 - loss: 0.1225 - val_accuracy: 0.7696 - val_loss: 1.3553
# Epoch 20/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9909 - loss: 0.1154 - val_accuracy: 0.7800 - val_loss: 1.1850
# Epoch 21/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9939 - loss: 0.0983 - val_accuracy: 0.7785 - val_loss: 1.2740
# Epoch 22/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9907 - loss: 0.1141 - val_accuracy: 0.7800 - val_loss: 1.4164
# Epoch 23/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9942 - loss: 0.0921 - val_accuracy: 0.7852 - val_loss: 1.1857
# Epoch 24/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9879 - loss: 0.1161 - val_accuracy: 0.7867 - val_loss: 1.2887
# Epoch 25/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9922 - loss: 0.0987 - val_accuracy: 0.7674 - val_loss: 1.3711
# Epoch 26/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9949 - loss: 0.0858 - val_accuracy: 0.7674 - val_loss: 1.4736
# Epoch 27/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9953 - loss: 0.0778 - val_accuracy: 0.7822 - val_loss: 1.3769
# Epoch 28/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9975 - loss: 0.0722 - val_accuracy: 0.7511 - val_loss: 1.5812
# Epoch 29/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9968 - loss: 0.0760 - val_accuracy: 0.7978 - val_loss: 1.3974
# Epoch 30/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9967 - loss: 0.0732 - val_accuracy: 0.7593 - val_loss: 1.6712
# Epoch 31/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9935 - loss: 0.0878 - val_accuracy: 0.7822 - val_loss: 1.4895
# Epoch 32/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9952 - loss: 0.0784 - val_accuracy: 0.7652 - val_loss: 1.6433
# Epoch 33/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9856 - loss: 0.1199 - val_accuracy: 0.7415 - val_loss: 1.5456
# Epoch 34/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9864 - loss: 0.1089 - val_accuracy: 0.7948 - val_loss: 1.2958
# Epoch 35/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9958 - loss: 0.0794 - val_accuracy: 0.7437 - val_loss: 1.7436
# Epoch 36/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9968 - loss: 0.0681 - val_accuracy: 0.7993 - val_loss: 1.3590
# Epoch 37/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9999 - loss: 0.0560 - val_accuracy: 0.7852 - val_loss: 1.5000
# Epoch 38/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 219ms/step - accuracy: 0.9985 - loss: 0.0588 - val_accuracy: 0.7652 - val_loss: 1.4399
# Epoch 39/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9959 - loss: 0.0727 - val_accuracy: 0.7237 - val_loss: 1.9325
# Epoch 40/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9881 - loss: 0.0977 - val_accuracy: 0.7896 - val_loss: 1.3874
# Epoch 41/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9949 - loss: 0.0711 - val_accuracy: 0.7533 - val_loss: 1.6905
# Epoch 42/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9914 - loss: 0.0820 - val_accuracy: 0.7904 - val_loss: 1.1818
# Epoch 43/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9964 - loss: 0.0626 - val_accuracy: 0.7978 - val_loss: 1.3562
# Epoch 44/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9984 - loss: 0.0549 - val_accuracy: 0.7867 - val_loss: 1.4747
# Epoch 45/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9969 - loss: 0.0626 - val_accuracy: 0.7859 - val_loss: 1.5399
# Epoch 46/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9988 - loss: 0.0524 - val_accuracy: 0.7896 - val_loss: 1.5357
# Epoch 47/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9948 - loss: 0.0747 - val_accuracy: 0.7978 - val_loss: 1.4673
# Epoch 48/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9944 - loss: 0.0703 - val_accuracy: 0.8274 - val_loss: 1.0799
# Epoch 49/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9978 - loss: 0.0532 - val_accuracy: 0.8230 - val_loss: 1.3128
# Epoch 50/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9958 - loss: 0.0670 - val_accuracy: 0.8037 - val_loss: 1.4669
# Epoch 51/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9973 - loss: 0.0590 - val_accuracy: 0.7378 - val_loss: 1.8498
# Epoch 52/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9920 - loss: 0.0761 - val_accuracy: 0.7911 - val_loss: 1.4865
# Epoch 53/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9978 - loss: 0.0535 - val_accuracy: 0.7733 - val_loss: 1.6392
# Epoch 54/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9961 - loss: 0.0602 - val_accuracy: 0.7733 - val_loss: 1.5040
# Epoch 55/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9957 - loss: 0.0595 - val_accuracy: 0.7837 - val_loss: 1.5356
# Epoch 56/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9955 - loss: 0.0634 - val_accuracy: 0.7881 - val_loss: 1.5111
# Epoch 57/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9983 - loss: 0.0470 - val_accuracy: 0.7859 - val_loss: 1.5845
# Epoch 58/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9957 - loss: 0.0599 - val_accuracy: 0.7511 - val_loss: 1.8438
# Epoch 59/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 217ms/step - accuracy: 0.9975 - loss: 0.0529 - val_accuracy: 0.7948 - val_loss: 1.4261
# Epoch 60/60
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 63s 218ms/step - accuracy: 0.9958 - loss: 0.0666 - val_accuracy: 0.7541 - val_loss: 1.6478

# %%
model.save('/content/drive/My Drive/Final-Year-Project/Dataset/Final-Version-of-Bird-Classification-Project/ML Models/Transfer Learning/ResNet50_melspectrogram_cqt_mfcc_balanced.keras')

# %%
visualize(history, 'mfcc_melspectrogram_cqt')

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['mfcc_melspectrogram_cqt'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['mfcc_melspectrogram_cqt'] = model.evaluate(validation_features, val_y)[-1]

# %%
val_scores['mfcc_melspectrogram_cqt'] = evaluate_model(val_y=val_y, val_yhat=val_yhat, val_yhat_result=val_yhat_result)

# %% [markdown]
# ## Review all the results

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(3)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(3)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Features')
result_df

# %%
val_scores_df = pd.DataFrame([(key, value['f1'], value['auc']) for key, value in val_scores.items()],
                             columns=['Features', 'F1_Score', 'AUC_Score']).round(3)

val_scores_df = val_scores_df.sort_values('Features')
print(val_scores_df)
