# %% [markdown]
# # **CNN**
# - Using data that was not annotated
# - Training it on the unbalanced data
# - Using avgpool
# - 6 second window

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard libraries
import numpy as np
import pandas as pd
import time
import os

# For audio
from IPython.display import Audio
import librosa

# For preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# For modeling
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Operational
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.ndimage
import pygame
import time
from scipy.signal import butter, filtfilt
import random
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pkl_path = '/content/drive/My Drive/Final-Year-Project/Dataset/Project-V4/feature-extraction/Annotated/NotAveragePooled/split_features_6s_all.pkl'

# Load the pickle file
with open(pkl_path, 'rb') as file:
    data = pickle.load(file)

# %%
train_data = data['train'].copy()
val_data = data['val'].copy()

# %%
# train_data]

# %%
train_labels = train_data['label'].copy()
temp = train_data.copy()
del temp['label']
tr_features = temp

# %%
val_labels = val_data['label'].copy()
temp = val_data.copy()
del temp['label']
v_features = temp

# %% [markdown]
# # Shuffle Data

# %%
def shuffle_data(input_label, input_features):
  input_len = len(input_label)
  np.random.seed(1826)
  input_indices = np.random.permutation(input_len)
  input_features = {key: np.array([input_features[key][i] for i in input_indices]) for key in input_features} # dictionary comprehension
  input_label = np.array([input_label[i] for i in input_indices])

  return input_label, input_features

# %%
train_y, train_features = shuffle_data(train_labels, tr_features)

# %%
val_y, val_features = shuffle_data(val_labels, v_features)

# %% [markdown]
# ## **LSTM Model**

# %%
def build_model(audio_features,
                learning_rate=0.001,
                gru=256,
                hidden=[128,128,32],
                dropout=0.5):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # add sequential model
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.GRU(gru, input_shape=(audio_features.shape[1],audio_features.shape[2])))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(dropout))

  for size in hidden:
    model.add(tf.keras.layers.Dense(size, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.015)))
    model.add(tf.keras.layers.Dropout(dropout))

  model.add(tf.keras.layers.Dense(units=20,activation='softmax'))

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Visualize the loss
    axes[0].plot(model_history.history['loss'], color='red', label='Training Loss')
    axes[0].plot(model_history.history['val_loss'], color='blue', label='Validation Loss')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss Progression', fontsize=14)
    axes[0].grid(True)
    axes[0].legend()

    # Visualize the accuracy
    axes[1].plot(model_history.history['accuracy'], color='green', label='Training Accuracy')
    axes[1].plot(model_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Accuracy Progression', fontsize=14)
    axes[1].grid(True)
    axes[1].legend()

    # Fine-tune layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
train_results = {}
val_results = {}

# %% [markdown]
# ### **With all the features**

# %%
# n_time = train_features['melspectrogram'].shape[2]

# mfcc_tiled = np.tile(train_features['mfcc'], (1, 3, 1))  # (3318, 60, 44), tiling 3 times to match 60 features
# chroma_tiled = np.tile(train_features['chroma'], (1, 5, 1))  # (3318, 60, 44), tiling 5 times to match 60 features
# rms_tiled = np.tile(train_features['rms'], (1, 60, 1))  # (3318, 60, 44), tiling 60 times to match 60 features

training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma'], train_features['rms']), axis=1)

print(training_features.shape)
# Out:
# (3954, 93, 259)

# %%
# mfcc_val_tiled = np.tile(val_features['mfcc'], (1, 3, 1))  # Tile to (n_samples_val, 60, 44)
# chroma_val_tiled = np.tile(val_features['chroma'], (1, 5, 1))  # Tile to (n_samples_val, 60, 44)
# rms_val_tiled = np.tile(val_features['rms'], (1, 60, 1))  # Tile to (n_samples_val, 60, 44)

# melspectrogram_val = val_features['melspectrogram']

validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma'], val_features['rms']), axis=1)

print(validation_features.shape)
# Out:
# (985, 93, 259)

# %% [markdown]
# Fit the model with training data

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=90
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             660 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 452,276 (1.73 MB)
#  Trainable params: 451,764 (1.72 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0724 - loss: 8.2558 - weighted_accuracy: 0.0724 - val_accuracy: 0.0599 - val_loss: 6.5583 - val_weighted_accuracy: 0.0599
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1340 - loss: 6.0554 - weighted_accuracy: 0.1340 - val_accuracy: 0.1421 - val_loss: 5.0299 - val_weighted_accuracy: 0.1421
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1637 - loss: 4.6045 - weighted_accuracy: 0.1637 - val_accuracy: 0.2416 - val_loss: 3.8457 - val_weighted_accuracy: 0.2416
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2164 - loss: 3.6500 - weighted_accuracy: 0.2164 - val_accuracy: 0.2711 - val_loss: 3.1463 - val_weighted_accuracy: 0.2711
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2217 - loss: 3.0961 - weighted_accuracy: 0.2217 - val_accuracy: 0.1431 - val_loss: 3.5316 - val_weighted_accuracy: 0.1431
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2442 - loss: 2.7236 - weighted_accuracy: 0.2442 - val_accuracy: 0.3381 - val_loss: 2.5020 - val_weighted_accuracy: 0.3381
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2891 - loss: 2.5463 - weighted_accuracy: 0.2891 - val_accuracy: 0.2467 - val_loss: 2.8048 - val_weighted_accuracy: 0.2467
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3101 - loss: 2.3667 - weighted_accuracy: 0.3101 - val_accuracy: 0.2548 - val_loss: 2.6684 - val_weighted_accuracy: 0.2548
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3334 - loss: 2.2454 - weighted_accuracy: 0.3334 - val_accuracy: 0.2853 - val_loss: 2.4655 - val_weighted_accuracy: 0.2853
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3616 - loss: 2.1442 - weighted_accuracy: 0.3616 - val_accuracy: 0.3807 - val_loss: 2.1631 - val_weighted_accuracy: 0.3807
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3668 - loss: 2.0913 - weighted_accuracy: 0.3668 - val_accuracy: 0.3980 - val_loss: 1.9823 - val_weighted_accuracy: 0.3980
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4167 - loss: 1.9631 - weighted_accuracy: 0.4167 - val_accuracy: 0.4000 - val_loss: 2.0180 - val_weighted_accuracy: 0.4000
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4240 - loss: 1.9111 - weighted_accuracy: 0.4240 - val_accuracy: 0.4091 - val_loss: 2.0348 - val_weighted_accuracy: 0.4091
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4182 - loss: 1.8815 - weighted_accuracy: 0.4182 - val_accuracy: 0.4000 - val_loss: 2.0326 - val_weighted_accuracy: 0.4000
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4439 - loss: 1.8046 - weighted_accuracy: 0.4439 - val_accuracy: 0.3736 - val_loss: 2.2470 - val_weighted_accuracy: 0.3736
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4738 - loss: 1.7667 - weighted_accuracy: 0.4738 - val_accuracy: 0.3574 - val_loss: 2.1925 - val_weighted_accuracy: 0.3574
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4784 - loss: 1.7279 - weighted_accuracy: 0.4784 - val_accuracy: 0.4670 - val_loss: 2.1778 - val_weighted_accuracy: 0.4670
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4857 - loss: 1.7108 - weighted_accuracy: 0.4857 - val_accuracy: 0.3513 - val_loss: 2.3068 - val_weighted_accuracy: 0.3513
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4747 - loss: 1.7499 - weighted_accuracy: 0.4747 - val_accuracy: 0.3848 - val_loss: 2.1725 - val_weighted_accuracy: 0.3848
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4992 - loss: 1.6812 - weighted_accuracy: 0.4992 - val_accuracy: 0.4761 - val_loss: 1.8809 - val_weighted_accuracy: 0.4761
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4931 - loss: 1.6626 - weighted_accuracy: 0.4931 - val_accuracy: 0.4701 - val_loss: 1.8896 - val_weighted_accuracy: 0.4701
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5246 - loss: 1.5664 - weighted_accuracy: 0.5246 - val_accuracy: 0.4812 - val_loss: 1.9288 - val_weighted_accuracy: 0.4812
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5533 - loss: 1.5660 - weighted_accuracy: 0.5533 - val_accuracy: 0.3695 - val_loss: 2.9013 - val_weighted_accuracy: 0.3695
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5209 - loss: 1.6069 - weighted_accuracy: 0.5209 - val_accuracy: 0.4183 - val_loss: 2.0014 - val_weighted_accuracy: 0.4183
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5459 - loss: 1.6073 - weighted_accuracy: 0.5459 - val_accuracy: 0.4863 - val_loss: 1.8081 - val_weighted_accuracy: 0.4863
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5608 - loss: 1.5101 - weighted_accuracy: 0.5608 - val_accuracy: 0.4467 - val_loss: 1.8640 - val_weighted_accuracy: 0.4467
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5749 - loss: 1.4687 - weighted_accuracy: 0.5749 - val_accuracy: 0.4477 - val_loss: 1.8575 - val_weighted_accuracy: 0.4477
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5637 - loss: 1.4849 - weighted_accuracy: 0.5637 - val_accuracy: 0.5208 - val_loss: 1.9553 - val_weighted_accuracy: 0.5208
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5763 - loss: 1.4723 - weighted_accuracy: 0.5763 - val_accuracy: 0.4619 - val_loss: 1.9543 - val_weighted_accuracy: 0.4619
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5715 - loss: 1.4694 - weighted_accuracy: 0.5715 - val_accuracy: 0.4934 - val_loss: 1.9067 - val_weighted_accuracy: 0.4934
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5903 - loss: 1.4346 - weighted_accuracy: 0.5903 - val_accuracy: 0.4487 - val_loss: 2.2317 - val_weighted_accuracy: 0.4487
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5982 - loss: 1.4058 - weighted_accuracy: 0.5982 - val_accuracy: 0.5472 - val_loss: 1.6469 - val_weighted_accuracy: 0.5472
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5909 - loss: 1.3907 - weighted_accuracy: 0.5909 - val_accuracy: 0.4518 - val_loss: 1.9023 - val_weighted_accuracy: 0.4518
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6111 - loss: 1.3689 - weighted_accuracy: 0.6111 - val_accuracy: 0.5442 - val_loss: 1.7693 - val_weighted_accuracy: 0.5442
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5998 - loss: 1.3528 - weighted_accuracy: 0.5998 - val_accuracy: 0.4701 - val_loss: 2.0243 - val_weighted_accuracy: 0.4701
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6163 - loss: 1.3694 - weighted_accuracy: 0.6163 - val_accuracy: 0.5086 - val_loss: 2.1315 - val_weighted_accuracy: 0.5086
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6093 - loss: 1.3530 - weighted_accuracy: 0.6093 - val_accuracy: 0.5452 - val_loss: 1.7884 - val_weighted_accuracy: 0.5452
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6189 - loss: 1.2713 - weighted_accuracy: 0.6189 - val_accuracy: 0.5675 - val_loss: 1.6291 - val_weighted_accuracy: 0.5675
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6279 - loss: 1.3068 - weighted_accuracy: 0.6279 - val_accuracy: 0.4893 - val_loss: 1.9457 - val_weighted_accuracy: 0.4893
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6015 - loss: 1.3295 - weighted_accuracy: 0.6015 - val_accuracy: 0.5695 - val_loss: 1.7059 - val_weighted_accuracy: 0.5695
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6208 - loss: 1.2695 - weighted_accuracy: 0.6208 - val_accuracy: 0.5249 - val_loss: 1.8496 - val_weighted_accuracy: 0.5249
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6325 - loss: 1.2783 - weighted_accuracy: 0.6325 - val_accuracy: 0.4721 - val_loss: 2.0887 - val_weighted_accuracy: 0.4721
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6444 - loss: 1.2128 - weighted_accuracy: 0.6444 - val_accuracy: 0.5777 - val_loss: 1.6885 - val_weighted_accuracy: 0.5777
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6382 - loss: 1.2355 - weighted_accuracy: 0.6382 - val_accuracy: 0.5736 - val_loss: 1.9314 - val_weighted_accuracy: 0.5736
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6580 - loss: 1.2083 - weighted_accuracy: 0.6580 - val_accuracy: 0.5056 - val_loss: 1.6977 - val_weighted_accuracy: 0.5056
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6531 - loss: 1.2351 - weighted_accuracy: 0.6531 - val_accuracy: 0.5655 - val_loss: 1.7678 - val_weighted_accuracy: 0.5655
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6454 - loss: 1.2269 - weighted_accuracy: 0.6454 - val_accuracy: 0.5827 - val_loss: 1.8596 - val_weighted_accuracy: 0.5827
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6469 - loss: 1.2368 - weighted_accuracy: 0.6469 - val_accuracy: 0.5482 - val_loss: 1.7413 - val_weighted_accuracy: 0.5482
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6475 - loss: 1.2133 - weighted_accuracy: 0.6475 - val_accuracy: 0.5858 - val_loss: 1.7977 - val_weighted_accuracy: 0.5858
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6866 - loss: 1.1292 - weighted_accuracy: 0.6866 - val_accuracy: 0.6071 - val_loss: 1.7093 - val_weighted_accuracy: 0.6071
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6770 - loss: 1.1746 - weighted_accuracy: 0.6770 - val_accuracy: 0.5665 - val_loss: 1.7226 - val_weighted_accuracy: 0.5665
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6570 - loss: 1.1823 - weighted_accuracy: 0.6570 - val_accuracy: 0.5817 - val_loss: 1.6361 - val_weighted_accuracy: 0.5817
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6875 - loss: 1.1130 - weighted_accuracy: 0.6875 - val_accuracy: 0.5645 - val_loss: 1.8170 - val_weighted_accuracy: 0.5645
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6858 - loss: 1.0823 - weighted_accuracy: 0.6858 - val_accuracy: 0.5838 - val_loss: 1.5855 - val_weighted_accuracy: 0.5838
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6955 - loss: 1.0967 - weighted_accuracy: 0.6955 - val_accuracy: 0.5878 - val_loss: 1.8044 - val_weighted_accuracy: 0.5878
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6892 - loss: 1.1719 - weighted_accuracy: 0.6892 - val_accuracy: 0.5807 - val_loss: 1.6489 - val_weighted_accuracy: 0.5807
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7041 - loss: 1.1018 - weighted_accuracy: 0.7041 - val_accuracy: 0.5959 - val_loss: 1.7560 - val_weighted_accuracy: 0.5959
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6986 - loss: 1.1173 - weighted_accuracy: 0.6986 - val_accuracy: 0.5695 - val_loss: 1.7513 - val_weighted_accuracy: 0.5695
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6893 - loss: 1.1215 - weighted_accuracy: 0.6893 - val_accuracy: 0.5503 - val_loss: 1.9979 - val_weighted_accuracy: 0.5503
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6979 - loss: 1.0793 - weighted_accuracy: 0.6979 - val_accuracy: 0.6284 - val_loss: 1.6995 - val_weighted_accuracy: 0.6284
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7020 - loss: 1.0768 - weighted_accuracy: 0.7020 - val_accuracy: 0.6234 - val_loss: 1.5378 - val_weighted_accuracy: 0.6234
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7029 - loss: 1.0807 - weighted_accuracy: 0.7029 - val_accuracy: 0.6081 - val_loss: 1.8722 - val_weighted_accuracy: 0.6081
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7100 - loss: 1.0678 - weighted_accuracy: 0.7100 - val_accuracy: 0.5655 - val_loss: 1.7899 - val_weighted_accuracy: 0.5655
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6956 - loss: 1.0689 - weighted_accuracy: 0.6956 - val_accuracy: 0.6010 - val_loss: 2.0732 - val_weighted_accuracy: 0.6010
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7238 - loss: 1.0525 - weighted_accuracy: 0.7238 - val_accuracy: 0.5807 - val_loss: 1.6868 - val_weighted_accuracy: 0.5807
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7114 - loss: 1.0857 - weighted_accuracy: 0.7114 - val_accuracy: 0.5746 - val_loss: 2.0102 - val_weighted_accuracy: 0.5746
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7192 - loss: 1.1064 - weighted_accuracy: 0.7192 - val_accuracy: 0.6305 - val_loss: 1.6422 - val_weighted_accuracy: 0.6305
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7184 - loss: 1.0592 - weighted_accuracy: 0.7184 - val_accuracy: 0.5513 - val_loss: 1.8365 - val_weighted_accuracy: 0.5513
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7324 - loss: 0.9828 - weighted_accuracy: 0.7324 - val_accuracy: 0.6091 - val_loss: 1.9082 - val_weighted_accuracy: 0.6091
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7305 - loss: 0.9757 - weighted_accuracy: 0.7305 - val_accuracy: 0.5574 - val_loss: 1.9026 - val_weighted_accuracy: 0.5574
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7252 - loss: 0.9856 - weighted_accuracy: 0.7252 - val_accuracy: 0.5259 - val_loss: 2.0366 - val_weighted_accuracy: 0.5259
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7118 - loss: 1.0512 - weighted_accuracy: 0.7118 - val_accuracy: 0.5685 - val_loss: 2.0318 - val_weighted_accuracy: 0.5685
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7321 - loss: 1.0202 - weighted_accuracy: 0.7321 - val_accuracy: 0.6132 - val_loss: 1.8073 - val_weighted_accuracy: 0.6132
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7364 - loss: 0.9880 - weighted_accuracy: 0.7364 - val_accuracy: 0.5827 - val_loss: 2.0813 - val_weighted_accuracy: 0.5827
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7524 - loss: 0.9323 - weighted_accuracy: 0.7524 - val_accuracy: 0.5898 - val_loss: 1.9186 - val_weighted_accuracy: 0.5898
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7518 - loss: 0.9081 - weighted_accuracy: 0.7518 - val_accuracy: 0.5959 - val_loss: 2.3404 - val_weighted_accuracy: 0.5959
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7599 - loss: 0.9504 - weighted_accuracy: 0.7599 - val_accuracy: 0.6234 - val_loss: 2.0484 - val_weighted_accuracy: 0.6234
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7369 - loss: 0.9681 - weighted_accuracy: 0.7369 - val_accuracy: 0.5695 - val_loss: 2.0206 - val_weighted_accuracy: 0.5695
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7597 - loss: 0.9454 - weighted_accuracy: 0.7597 - val_accuracy: 0.6315 - val_loss: 2.0888 - val_weighted_accuracy: 0.6315
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7532 - loss: 0.9565 - weighted_accuracy: 0.7532 - val_accuracy: 0.5990 - val_loss: 1.9260 - val_weighted_accuracy: 0.5990
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7490 - loss: 0.9759 - weighted_accuracy: 0.7490 - val_accuracy: 0.5980 - val_loss: 1.7114 - val_weighted_accuracy: 0.5980
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7665 - loss: 0.9374 - weighted_accuracy: 0.7665 - val_accuracy: 0.6203 - val_loss: 2.1985 - val_weighted_accuracy: 0.6203
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7619 - loss: 0.9365 - weighted_accuracy: 0.7619 - val_accuracy: 0.6629 - val_loss: 1.8524 - val_weighted_accuracy: 0.6629
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7558 - loss: 0.9221 - weighted_accuracy: 0.7558 - val_accuracy: 0.5990 - val_loss: 1.7443 - val_weighted_accuracy: 0.5990
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7682 - loss: 0.9079 - weighted_accuracy: 0.7682 - val_accuracy: 0.6152 - val_loss: 1.9407 - val_weighted_accuracy: 0.6152
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7871 - loss: 0.8893 - weighted_accuracy: 0.7871 - val_accuracy: 0.6162 - val_loss: 1.8368 - val_weighted_accuracy: 0.6162
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7624 - loss: 0.9208 - weighted_accuracy: 0.7624 - val_accuracy: 0.6467 - val_loss: 2.1428 - val_weighted_accuracy: 0.6467
# Epoch 88/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7547 - loss: 0.9654 - weighted_accuracy: 0.7547 - val_accuracy: 0.5523 - val_loss: 2.4576 - val_weighted_accuracy: 0.5523
# Epoch 89/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7730 - loss: 0.9317 - weighted_accuracy: 0.7730 - val_accuracy: 0.5959 - val_loss: 2.0553 - val_weighted_accuracy: 0.5959
# Epoch 90/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7792 - loss: 0.8942 - weighted_accuracy: 0.7792 - val_accuracy: 0.6457 - val_loss: 1.8825 - val_weighted_accuracy: 0.6457
# Epoch 91/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7850 - loss: 0.9037 - weighted_accuracy: 0.7850 - val_accuracy: 0.6183 - val_loss: 2.0538 - val_weighted_accuracy: 0.6183
# Epoch 92/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7943 - loss: 0.8578 - weighted_accuracy: 0.7943 - val_accuracy: 0.6183 - val_loss: 2.0457 - val_weighted_accuracy: 0.6183
# Epoch 93/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7893 - loss: 0.8909 - weighted_accuracy: 0.7893 - val_accuracy: 0.5574 - val_loss: 2.1906 - val_weighted_accuracy: 0.5574
# Epoch 94/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7574 - loss: 0.9719 - weighted_accuracy: 0.7574 - val_accuracy: 0.6213 - val_loss: 2.1931 - val_weighted_accuracy: 0.6213
# Epoch 95/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7945 - loss: 0.8364 - weighted_accuracy: 0.7945 - val_accuracy: 0.6365 - val_loss: 2.0299 - val_weighted_accuracy: 0.6365
# Epoch 96/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7838 - loss: 0.8691 - weighted_accuracy: 0.7838 - val_accuracy: 0.5827 - val_loss: 2.3097 - val_weighted_accuracy: 0.5827
# Epoch 97/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7977 - loss: 0.8751 - weighted_accuracy: 0.7977 - val_accuracy: 0.6142 - val_loss: 2.2307 - val_weighted_accuracy: 0.6142
# Epoch 98/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7535 - loss: 0.9958 - weighted_accuracy: 0.7535 - val_accuracy: 0.6345 - val_loss: 2.1235 - val_weighted_accuracy: 0.6345
# Epoch 99/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7807 - loss: 0.8932 - weighted_accuracy: 0.7807 - val_accuracy: 0.6183 - val_loss: 2.1707 - val_weighted_accuracy: 0.6183
# Epoch 100/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8185 - loss: 0.8185 - weighted_accuracy: 0.8185 - val_accuracy: 0.6335 - val_loss: 2.2732 - val_weighted_accuracy: 0.6335

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['all_features'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['all_features'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8881 - loss: 0.6279 - weighted_accuracy: 0.8881
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6313 - loss: 2.1123 - weighted_accuracy: 0.6313

# %% [markdown]
# ## **With Mel-Spectrogram, MFCCs, Chroma**

# %%
training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma']), axis=1)

print(training_features.shape)
# Out:
# (3954, 92, 259)

# %%
validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma']), axis=1)

print(validation_features.shape)
# Out:
# (985, 92, 259)

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=90
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             660 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 452,276 (1.73 MB)
#  Trainable params: 451,764 (1.72 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0638 - loss: 8.4348 - weighted_accuracy: 0.0638 - val_accuracy: 0.1381 - val_loss: 6.6611 - val_weighted_accuracy: 0.1381
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1247 - loss: 6.2105 - weighted_accuracy: 0.1247 - val_accuracy: 0.1208 - val_loss: 5.0871 - val_weighted_accuracy: 0.1208
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1688 - loss: 4.7476 - weighted_accuracy: 0.1688 - val_accuracy: 0.1584 - val_loss: 4.0531 - val_weighted_accuracy: 0.1584
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1857 - loss: 3.8319 - weighted_accuracy: 0.1857 - val_accuracy: 0.2477 - val_loss: 3.2448 - val_weighted_accuracy: 0.2477
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2074 - loss: 3.2064 - weighted_accuracy: 0.2074 - val_accuracy: 0.1218 - val_loss: 3.0828 - val_weighted_accuracy: 0.1218
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2177 - loss: 2.8350 - weighted_accuracy: 0.2177 - val_accuracy: 0.1655 - val_loss: 2.8530 - val_weighted_accuracy: 0.1655
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2518 - loss: 2.6210 - weighted_accuracy: 0.2518 - val_accuracy: 0.2914 - val_loss: 2.4593 - val_weighted_accuracy: 0.2914
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2740 - loss: 2.4851 - weighted_accuracy: 0.2740 - val_accuracy: 0.2274 - val_loss: 2.5431 - val_weighted_accuracy: 0.2274
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2967 - loss: 2.3377 - weighted_accuracy: 0.2967 - val_accuracy: 0.2426 - val_loss: 2.4376 - val_weighted_accuracy: 0.2426
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3193 - loss: 2.2660 - weighted_accuracy: 0.3193 - val_accuracy: 0.2741 - val_loss: 2.6092 - val_weighted_accuracy: 0.2741
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3375 - loss: 2.1569 - weighted_accuracy: 0.3375 - val_accuracy: 0.3462 - val_loss: 2.3308 - val_weighted_accuracy: 0.3462
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3495 - loss: 2.0879 - weighted_accuracy: 0.3495 - val_accuracy: 0.3371 - val_loss: 2.3050 - val_weighted_accuracy: 0.3371
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3753 - loss: 2.0321 - weighted_accuracy: 0.3753 - val_accuracy: 0.3594 - val_loss: 2.1024 - val_weighted_accuracy: 0.3594
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3992 - loss: 1.9342 - weighted_accuracy: 0.3992 - val_accuracy: 0.3614 - val_loss: 2.0110 - val_weighted_accuracy: 0.3614
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3939 - loss: 1.8898 - weighted_accuracy: 0.3939 - val_accuracy: 0.3168 - val_loss: 2.2483 - val_weighted_accuracy: 0.3168
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4041 - loss: 1.8977 - weighted_accuracy: 0.4041 - val_accuracy: 0.4223 - val_loss: 1.8855 - val_weighted_accuracy: 0.4223
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4309 - loss: 1.8355 - weighted_accuracy: 0.4309 - val_accuracy: 0.3289 - val_loss: 2.1653 - val_weighted_accuracy: 0.3289
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4416 - loss: 1.7927 - weighted_accuracy: 0.4416 - val_accuracy: 0.3553 - val_loss: 2.0619 - val_weighted_accuracy: 0.3553
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4509 - loss: 1.7286 - weighted_accuracy: 0.4509 - val_accuracy: 0.4193 - val_loss: 2.0211 - val_weighted_accuracy: 0.4193
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4767 - loss: 1.7008 - weighted_accuracy: 0.4767 - val_accuracy: 0.4548 - val_loss: 1.9030 - val_weighted_accuracy: 0.4548
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4723 - loss: 1.7164 - weighted_accuracy: 0.4723 - val_accuracy: 0.4213 - val_loss: 1.9253 - val_weighted_accuracy: 0.4213
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4859 - loss: 1.6425 - weighted_accuracy: 0.4859 - val_accuracy: 0.4538 - val_loss: 1.9066 - val_weighted_accuracy: 0.4538
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4715 - loss: 1.7046 - weighted_accuracy: 0.4715 - val_accuracy: 0.4629 - val_loss: 1.9238 - val_weighted_accuracy: 0.4629
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4851 - loss: 1.6646 - weighted_accuracy: 0.4851 - val_accuracy: 0.4863 - val_loss: 1.8083 - val_weighted_accuracy: 0.4863
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5186 - loss: 1.5806 - weighted_accuracy: 0.5186 - val_accuracy: 0.4843 - val_loss: 1.8101 - val_weighted_accuracy: 0.4843
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5022 - loss: 1.5566 - weighted_accuracy: 0.5022 - val_accuracy: 0.4030 - val_loss: 1.9685 - val_weighted_accuracy: 0.4030
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5210 - loss: 1.5418 - weighted_accuracy: 0.5210 - val_accuracy: 0.5036 - val_loss: 2.0649 - val_weighted_accuracy: 0.5036
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5282 - loss: 1.5427 - weighted_accuracy: 0.5282 - val_accuracy: 0.4954 - val_loss: 1.7113 - val_weighted_accuracy: 0.4954
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5142 - loss: 1.5683 - weighted_accuracy: 0.5142 - val_accuracy: 0.5330 - val_loss: 1.6338 - val_weighted_accuracy: 0.5330
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5342 - loss: 1.4974 - weighted_accuracy: 0.5342 - val_accuracy: 0.5239 - val_loss: 1.7317 - val_weighted_accuracy: 0.5239
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5404 - loss: 1.5091 - weighted_accuracy: 0.5404 - val_accuracy: 0.5188 - val_loss: 1.7805 - val_weighted_accuracy: 0.5188
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5499 - loss: 1.5026 - weighted_accuracy: 0.5499 - val_accuracy: 0.5472 - val_loss: 1.6739 - val_weighted_accuracy: 0.5472
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5601 - loss: 1.4665 - weighted_accuracy: 0.5601 - val_accuracy: 0.5695 - val_loss: 1.7624 - val_weighted_accuracy: 0.5695
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5538 - loss: 1.4405 - weighted_accuracy: 0.5538 - val_accuracy: 0.5543 - val_loss: 1.8471 - val_weighted_accuracy: 0.5543
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5516 - loss: 1.4574 - weighted_accuracy: 0.5516 - val_accuracy: 0.5492 - val_loss: 1.7631 - val_weighted_accuracy: 0.5492
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5596 - loss: 1.4683 - weighted_accuracy: 0.5596 - val_accuracy: 0.5777 - val_loss: 1.6204 - val_weighted_accuracy: 0.5777
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5963 - loss: 1.3847 - weighted_accuracy: 0.5963 - val_accuracy: 0.5249 - val_loss: 1.8101 - val_weighted_accuracy: 0.5249
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5645 - loss: 1.4107 - weighted_accuracy: 0.5645 - val_accuracy: 0.5330 - val_loss: 1.6872 - val_weighted_accuracy: 0.5330
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5798 - loss: 1.3904 - weighted_accuracy: 0.5798 - val_accuracy: 0.5949 - val_loss: 1.7009 - val_weighted_accuracy: 0.5949
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5849 - loss: 1.3580 - weighted_accuracy: 0.5849 - val_accuracy: 0.5533 - val_loss: 1.8170 - val_weighted_accuracy: 0.5533
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6031 - loss: 1.3195 - weighted_accuracy: 0.6031 - val_accuracy: 0.5746 - val_loss: 1.8064 - val_weighted_accuracy: 0.5746
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6041 - loss: 1.3630 - weighted_accuracy: 0.6041 - val_accuracy: 0.4599 - val_loss: 1.7240 - val_weighted_accuracy: 0.4599
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5931 - loss: 1.3749 - weighted_accuracy: 0.5931 - val_accuracy: 0.5371 - val_loss: 1.8000 - val_weighted_accuracy: 0.5371
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6231 - loss: 1.3090 - weighted_accuracy: 0.6231 - val_accuracy: 0.5807 - val_loss: 1.6089 - val_weighted_accuracy: 0.5807
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6278 - loss: 1.2549 - weighted_accuracy: 0.6278 - val_accuracy: 0.5523 - val_loss: 1.6618 - val_weighted_accuracy: 0.5523
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6299 - loss: 1.2666 - weighted_accuracy: 0.6299 - val_accuracy: 0.5157 - val_loss: 1.8410 - val_weighted_accuracy: 0.5157
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6123 - loss: 1.2991 - weighted_accuracy: 0.6123 - val_accuracy: 0.5624 - val_loss: 1.7897 - val_weighted_accuracy: 0.5624
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6496 - loss: 1.1998 - weighted_accuracy: 0.6496 - val_accuracy: 0.5848 - val_loss: 1.7371 - val_weighted_accuracy: 0.5848
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6322 - loss: 1.2452 - weighted_accuracy: 0.6322 - val_accuracy: 0.5553 - val_loss: 1.8574 - val_weighted_accuracy: 0.5553
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6307 - loss: 1.2501 - weighted_accuracy: 0.6307 - val_accuracy: 0.6010 - val_loss: 1.5713 - val_weighted_accuracy: 0.6010
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6323 - loss: 1.2350 - weighted_accuracy: 0.6323 - val_accuracy: 0.5990 - val_loss: 1.5494 - val_weighted_accuracy: 0.5990
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6505 - loss: 1.1913 - weighted_accuracy: 0.6505 - val_accuracy: 0.5787 - val_loss: 1.6729 - val_weighted_accuracy: 0.5787
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6450 - loss: 1.2015 - weighted_accuracy: 0.6450 - val_accuracy: 0.5381 - val_loss: 1.7657 - val_weighted_accuracy: 0.5381
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6195 - loss: 1.2608 - weighted_accuracy: 0.6195 - val_accuracy: 0.5431 - val_loss: 1.6037 - val_weighted_accuracy: 0.5431
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6516 - loss: 1.1432 - weighted_accuracy: 0.6516 - val_accuracy: 0.6030 - val_loss: 1.6410 - val_weighted_accuracy: 0.6030
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6516 - loss: 1.1787 - weighted_accuracy: 0.6516 - val_accuracy: 0.6152 - val_loss: 1.5524 - val_weighted_accuracy: 0.6152
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6623 - loss: 1.1850 - weighted_accuracy: 0.6623 - val_accuracy: 0.4792 - val_loss: 1.8721 - val_weighted_accuracy: 0.4792
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6659 - loss: 1.1269 - weighted_accuracy: 0.6659 - val_accuracy: 0.6061 - val_loss: 1.6605 - val_weighted_accuracy: 0.6061
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6595 - loss: 1.1959 - weighted_accuracy: 0.6595 - val_accuracy: 0.5959 - val_loss: 1.6372 - val_weighted_accuracy: 0.5959
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6598 - loss: 1.1588 - weighted_accuracy: 0.6598 - val_accuracy: 0.5472 - val_loss: 1.9897 - val_weighted_accuracy: 0.5472
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6614 - loss: 1.1391 - weighted_accuracy: 0.6614 - val_accuracy: 0.6112 - val_loss: 1.6375 - val_weighted_accuracy: 0.6112
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6508 - loss: 1.1639 - weighted_accuracy: 0.6508 - val_accuracy: 0.5797 - val_loss: 1.7996 - val_weighted_accuracy: 0.5797
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6125 - loss: 1.3596 - weighted_accuracy: 0.6125 - val_accuracy: 0.5878 - val_loss: 1.8238 - val_weighted_accuracy: 0.5878
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6550 - loss: 1.1930 - weighted_accuracy: 0.6550 - val_accuracy: 0.6000 - val_loss: 1.6982 - val_weighted_accuracy: 0.6000
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6828 - loss: 1.0617 - weighted_accuracy: 0.6828 - val_accuracy: 0.6234 - val_loss: 1.6571 - val_weighted_accuracy: 0.6234
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6671 - loss: 1.1055 - weighted_accuracy: 0.6671 - val_accuracy: 0.6081 - val_loss: 1.8522 - val_weighted_accuracy: 0.6081
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6788 - loss: 1.0725 - weighted_accuracy: 0.6788 - val_accuracy: 0.5645 - val_loss: 1.5584 - val_weighted_accuracy: 0.5645
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6617 - loss: 1.1311 - weighted_accuracy: 0.6617 - val_accuracy: 0.6325 - val_loss: 1.5767 - val_weighted_accuracy: 0.6325
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6857 - loss: 1.0819 - weighted_accuracy: 0.6857 - val_accuracy: 0.5868 - val_loss: 1.8220 - val_weighted_accuracy: 0.5868
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6681 - loss: 1.1612 - weighted_accuracy: 0.6681 - val_accuracy: 0.6213 - val_loss: 1.6993 - val_weighted_accuracy: 0.6213
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6764 - loss: 1.0927 - weighted_accuracy: 0.6764 - val_accuracy: 0.5523 - val_loss: 2.0669 - val_weighted_accuracy: 0.5523
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6942 - loss: 1.0560 - weighted_accuracy: 0.6942 - val_accuracy: 0.6234 - val_loss: 1.8337 - val_weighted_accuracy: 0.6234
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6662 - loss: 1.0952 - weighted_accuracy: 0.6662 - val_accuracy: 0.5766 - val_loss: 1.9659 - val_weighted_accuracy: 0.5766
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6990 - loss: 1.0440 - weighted_accuracy: 0.6990 - val_accuracy: 0.5574 - val_loss: 2.0518 - val_weighted_accuracy: 0.5574
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7034 - loss: 1.0273 - weighted_accuracy: 0.7034 - val_accuracy: 0.5878 - val_loss: 1.9046 - val_weighted_accuracy: 0.5878
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6892 - loss: 1.0593 - weighted_accuracy: 0.6892 - val_accuracy: 0.6406 - val_loss: 1.6305 - val_weighted_accuracy: 0.6406
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6858 - loss: 1.0519 - weighted_accuracy: 0.6858 - val_accuracy: 0.6223 - val_loss: 1.6632 - val_weighted_accuracy: 0.6223
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7166 - loss: 0.9972 - weighted_accuracy: 0.7166 - val_accuracy: 0.6132 - val_loss: 1.8950 - val_weighted_accuracy: 0.6132
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6839 - loss: 1.0087 - weighted_accuracy: 0.6839 - val_accuracy: 0.6416 - val_loss: 1.7337 - val_weighted_accuracy: 0.6416
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6824 - loss: 1.0374 - weighted_accuracy: 0.6824 - val_accuracy: 0.5898 - val_loss: 1.9923 - val_weighted_accuracy: 0.5898
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6957 - loss: 1.0499 - weighted_accuracy: 0.6957 - val_accuracy: 0.6376 - val_loss: 1.7324 - val_weighted_accuracy: 0.6376
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7096 - loss: 1.0013 - weighted_accuracy: 0.7096 - val_accuracy: 0.5919 - val_loss: 1.9250 - val_weighted_accuracy: 0.5919
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7071 - loss: 1.0512 - weighted_accuracy: 0.7071 - val_accuracy: 0.6345 - val_loss: 1.6229 - val_weighted_accuracy: 0.6345
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7013 - loss: 1.0221 - weighted_accuracy: 0.7013 - val_accuracy: 0.6193 - val_loss: 1.7137 - val_weighted_accuracy: 0.6193
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7302 - loss: 0.9354 - weighted_accuracy: 0.7302 - val_accuracy: 0.6010 - val_loss: 1.9700 - val_weighted_accuracy: 0.6010
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7088 - loss: 1.0232 - weighted_accuracy: 0.7088 - val_accuracy: 0.6274 - val_loss: 1.8424 - val_weighted_accuracy: 0.6274
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7088 - loss: 0.9953 - weighted_accuracy: 0.7088 - val_accuracy: 0.5929 - val_loss: 2.1402 - val_weighted_accuracy: 0.5929
# Epoch 88/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6709 - loss: 1.1494 - weighted_accuracy: 0.6709 - val_accuracy: 0.6396 - val_loss: 1.6444 - val_weighted_accuracy: 0.6396
# Epoch 89/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7107 - loss: 1.0014 - weighted_accuracy: 0.7107 - val_accuracy: 0.5970 - val_loss: 1.8445 - val_weighted_accuracy: 0.5970
# Epoch 90/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7032 - loss: 0.9981 - weighted_accuracy: 0.7032 - val_accuracy: 0.6051 - val_loss: 1.8269 - val_weighted_accuracy: 0.6051
# Epoch 91/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7025 - loss: 1.0102 - weighted_accuracy: 0.7025 - val_accuracy: 0.6041 - val_loss: 1.6174 - val_weighted_accuracy: 0.6041
# Epoch 92/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7080 - loss: 0.9964 - weighted_accuracy: 0.7080 - val_accuracy: 0.6528 - val_loss: 1.8549 - val_weighted_accuracy: 0.6528
# Epoch 93/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7175 - loss: 0.9740 - weighted_accuracy: 0.7175 - val_accuracy: 0.5543 - val_loss: 1.9312 - val_weighted_accuracy: 0.5543
# Epoch 94/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6944 - loss: 1.0244 - weighted_accuracy: 0.6944 - val_accuracy: 0.5868 - val_loss: 2.5508 - val_weighted_accuracy: 0.5868
# Epoch 95/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7079 - loss: 1.0762 - weighted_accuracy: 0.7079 - val_accuracy: 0.6264 - val_loss: 1.8581 - val_weighted_accuracy: 0.6264
# Epoch 96/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6976 - loss: 1.1069 - weighted_accuracy: 0.6976 - val_accuracy: 0.6467 - val_loss: 1.6987 - val_weighted_accuracy: 0.6467
# Epoch 97/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7180 - loss: 0.9746 - weighted_accuracy: 0.7180 - val_accuracy: 0.5777 - val_loss: 1.6924 - val_weighted_accuracy: 0.5777
# Epoch 98/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7056 - loss: 0.9792 - weighted_accuracy: 0.7056 - val_accuracy: 0.6132 - val_loss: 2.0601 - val_weighted_accuracy: 0.6132
# Epoch 99/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7059 - loss: 0.9898 - weighted_accuracy: 0.7059 - val_accuracy: 0.6386 - val_loss: 1.7225 - val_weighted_accuracy: 0.6386
# Epoch 100/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7282 - loss: 0.9648 - weighted_accuracy: 0.7282 - val_accuracy: 0.6376 - val_loss: 1.8095 - val_weighted_accuracy: 0.6376

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['melspectrogram_chroma_mfcc'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['melspectrogram_chroma_mfcc'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7651 - loss: 0.8449 - weighted_accuracy: 0.7651
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5700 - loss: 1.6677 - weighted_accuracy: 0.5700

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(3)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(3)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Features')
result_df
# Out:
#                      Features  Train_Accuracy  Val_Accuracy
# 0                all_features           0.895         0.637
# 1  melspectrogram_chroma_mfcc           0.771         0.604
