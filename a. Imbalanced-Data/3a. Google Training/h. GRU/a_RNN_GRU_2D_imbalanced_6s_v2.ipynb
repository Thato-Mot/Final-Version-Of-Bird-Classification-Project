# %% [markdown]
# # **CNN**
# - Using data that was not annotated
# - Training it on the unbalanced data
# - Using avgpool
# - 6 second window

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard libraries
import numpy as np
import pandas as pd
import time
import os

# For audio
from IPython.display import Audio
import librosa

# For preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# For modeling
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Operational
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.ndimage
import pygame
import time
from scipy.signal import butter, filtfilt
import random
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pkl_path = '/content/drive/My Drive/Final-Year-Project/Dataset/Project-V4/feature-extraction/Annotated/NotAveragePooled/split_features_6s_all.pkl'

# Load the pickle file
with open(pkl_path, 'rb') as file:
    data = pickle.load(file)

# %%
train_data = data['train'].copy()
val_data = data['val'].copy()

# %%
# train_data]

# %%
train_labels = train_data['label'].copy()
temp = train_data.copy()
del temp['label']
tr_features = temp

# %%
val_labels = val_data['label'].copy()
temp = val_data.copy()
del temp['label']
v_features = temp

# %% [markdown]
# # Shuffle Data

# %%
def shuffle_data(input_label, input_features):
  input_len = len(input_label)
  np.random.seed(1826)
  input_indices = np.random.permutation(input_len)
  input_features = {key: np.array([input_features[key][i] for i in input_indices]) for key in input_features} # dictionary comprehension
  input_label = np.array([input_label[i] for i in input_indices])

  return input_label, input_features

# %%
train_y, train_features = shuffle_data(train_labels, tr_features)

# %%
val_y, val_features = shuffle_data(val_labels, v_features)

# %% [markdown]
# ## **LSTM Model**

# %%
def build_model(audio_features,
                learning_rate=0.001,
                gru=512,
                hidden=[256,128,64],
                dropout=0.3):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # add sequential model
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.GRU(gru, input_shape=(audio_features.shape[1],audio_features.shape[2])))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(dropout))

  for size in hidden:
    model.add(tf.keras.layers.Dense(size, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
    model.add(tf.keras.layers.Dropout(dropout))

  model.add(tf.keras.layers.Dense(units=20,activation='softmax'))

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Visualize the loss
    axes[0].plot(model_history.history['loss'], color='red', label='Training Loss')
    axes[0].plot(model_history.history['val_loss'], color='blue', label='Validation Loss')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss Progression', fontsize=14)
    axes[0].grid(True)
    axes[0].legend()

    # Visualize the accuracy
    axes[1].plot(model_history.history['accuracy'], color='green', label='Training Accuracy')
    axes[1].plot(model_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Accuracy Progression', fontsize=14)
    axes[1].grid(True)
    axes[1].legend()

    # Fine-tune layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
train_results = {}
val_results = {}

# %% [markdown]
# ### **With all the features**

# %%
# n_time = train_features['melspectrogram'].shape[2]

# mfcc_tiled = np.tile(train_features['mfcc'], (1, 3, 1))  # (3318, 60, 44), tiling 3 times to match 60 features
# chroma_tiled = np.tile(train_features['chroma'], (1, 5, 1))  # (3318, 60, 44), tiling 5 times to match 60 features
# rms_tiled = np.tile(train_features['rms'], (1, 60, 1))  # (3318, 60, 44), tiling 60 times to match 60 features

training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma'], train_features['rms']), axis=1)

print(training_features.shape)
# Out:
# (3954, 93, 259)

# %%
# mfcc_val_tiled = np.tile(val_features['mfcc'], (1, 3, 1))  # Tile to (n_samples_val, 60, 44)
# chroma_val_tiled = np.tile(val_features['chroma'], (1, 5, 1))  # Tile to (n_samples_val, 60, 44)
# rms_val_tiled = np.tile(val_features['rms'], (1, 60, 1))  # Tile to (n_samples_val, 60, 44)

# melspectrogram_val = val_features['melspectrogram']

validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma'], val_features['rms']), axis=1)

print(validation_features.shape)
# Out:
# (985, 93, 259)

# %% [markdown]
# Fit the model with training data

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 512)                 │       1,187,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │           1,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,363,156 (5.20 MB)
#  Trainable params: 1,362,132 (5.20 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1607 - loss: 2.9255 - weighted_accuracy: 0.1607 - val_accuracy: 0.0934 - val_loss: 2.9100 - val_weighted_accuracy: 0.0934
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.3204 - loss: 2.2348 - weighted_accuracy: 0.3204 - val_accuracy: 0.2376 - val_loss: 2.5350 - val_weighted_accuracy: 0.2376
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.3842 - loss: 1.9704 - weighted_accuracy: 0.3842 - val_accuracy: 0.2000 - val_loss: 2.4553 - val_weighted_accuracy: 0.2000
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4721 - loss: 1.6932 - weighted_accuracy: 0.4721 - val_accuracy: 0.3431 - val_loss: 2.2851 - val_weighted_accuracy: 0.3431
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4955 - loss: 1.5850 - weighted_accuracy: 0.4955 - val_accuracy: 0.3706 - val_loss: 2.2111 - val_weighted_accuracy: 0.3706
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5345 - loss: 1.4177 - weighted_accuracy: 0.5345 - val_accuracy: 0.4020 - val_loss: 1.8371 - val_weighted_accuracy: 0.4020
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5796 - loss: 1.2941 - weighted_accuracy: 0.5796 - val_accuracy: 0.3391 - val_loss: 2.2542 - val_weighted_accuracy: 0.3391
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5981 - loss: 1.2089 - weighted_accuracy: 0.5981 - val_accuracy: 0.3970 - val_loss: 2.0546 - val_weighted_accuracy: 0.3970
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6269 - loss: 1.1586 - weighted_accuracy: 0.6269 - val_accuracy: 0.3533 - val_loss: 2.3579 - val_weighted_accuracy: 0.3533
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6526 - loss: 1.0914 - weighted_accuracy: 0.6526 - val_accuracy: 0.0680 - val_loss: 5.8844 - val_weighted_accuracy: 0.0680
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6557 - loss: 1.0520 - weighted_accuracy: 0.6557 - val_accuracy: 0.4386 - val_loss: 2.6582 - val_weighted_accuracy: 0.4386
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6807 - loss: 0.9875 - weighted_accuracy: 0.6807 - val_accuracy: 0.5025 - val_loss: 1.5939 - val_weighted_accuracy: 0.5025
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6975 - loss: 0.9351 - weighted_accuracy: 0.6975 - val_accuracy: 0.5056 - val_loss: 1.7413 - val_weighted_accuracy: 0.5056
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7095 - loss: 0.9355 - weighted_accuracy: 0.7095 - val_accuracy: 0.5360 - val_loss: 1.5282 - val_weighted_accuracy: 0.5360
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7425 - loss: 0.8388 - weighted_accuracy: 0.7425 - val_accuracy: 0.3492 - val_loss: 4.0156 - val_weighted_accuracy: 0.3492
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7664 - loss: 0.7831 - weighted_accuracy: 0.7664 - val_accuracy: 0.4345 - val_loss: 2.0360 - val_weighted_accuracy: 0.4345
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7711 - loss: 0.7559 - weighted_accuracy: 0.7711 - val_accuracy: 0.5269 - val_loss: 1.6979 - val_weighted_accuracy: 0.5269
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7870 - loss: 0.7480 - weighted_accuracy: 0.7870 - val_accuracy: 0.6051 - val_loss: 1.5505 - val_weighted_accuracy: 0.6051
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8009 - loss: 0.6540 - weighted_accuracy: 0.8009 - val_accuracy: 0.5360 - val_loss: 2.1450 - val_weighted_accuracy: 0.5360
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8146 - loss: 0.6257 - weighted_accuracy: 0.8146 - val_accuracy: 0.5472 - val_loss: 1.6521 - val_weighted_accuracy: 0.5472
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8219 - loss: 0.6366 - weighted_accuracy: 0.8219 - val_accuracy: 0.5452 - val_loss: 1.4285 - val_weighted_accuracy: 0.5452
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8386 - loss: 0.5788 - weighted_accuracy: 0.8386 - val_accuracy: 0.5218 - val_loss: 2.0037 - val_weighted_accuracy: 0.5218
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8368 - loss: 0.5806 - weighted_accuracy: 0.8368 - val_accuracy: 0.6152 - val_loss: 1.7530 - val_weighted_accuracy: 0.6152
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8363 - loss: 0.5536 - weighted_accuracy: 0.8363 - val_accuracy: 0.5584 - val_loss: 1.8053 - val_weighted_accuracy: 0.5584
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8433 - loss: 0.5577 - weighted_accuracy: 0.8433 - val_accuracy: 0.5452 - val_loss: 2.0465 - val_weighted_accuracy: 0.5452
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8374 - loss: 0.5862 - weighted_accuracy: 0.8374 - val_accuracy: 0.6142 - val_loss: 1.4926 - val_weighted_accuracy: 0.6142
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8536 - loss: 0.5076 - weighted_accuracy: 0.8536 - val_accuracy: 0.4376 - val_loss: 3.0235 - val_weighted_accuracy: 0.4376
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8647 - loss: 0.5032 - weighted_accuracy: 0.8647 - val_accuracy: 0.6365 - val_loss: 1.4502 - val_weighted_accuracy: 0.6365
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8839 - loss: 0.4446 - weighted_accuracy: 0.8839 - val_accuracy: 0.6315 - val_loss: 1.3848 - val_weighted_accuracy: 0.6315
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8986 - loss: 0.4272 - weighted_accuracy: 0.8986 - val_accuracy: 0.5868 - val_loss: 1.6535 - val_weighted_accuracy: 0.5868
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8853 - loss: 0.4481 - weighted_accuracy: 0.8853 - val_accuracy: 0.6335 - val_loss: 1.8886 - val_weighted_accuracy: 0.6335
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8992 - loss: 0.4227 - weighted_accuracy: 0.8992 - val_accuracy: 0.6569 - val_loss: 1.2541 - val_weighted_accuracy: 0.6569
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9064 - loss: 0.3904 - weighted_accuracy: 0.9064 - val_accuracy: 0.5147 - val_loss: 2.7643 - val_weighted_accuracy: 0.5147
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8929 - loss: 0.4220 - weighted_accuracy: 0.8929 - val_accuracy: 0.6071 - val_loss: 1.7254 - val_weighted_accuracy: 0.6071
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9040 - loss: 0.3793 - weighted_accuracy: 0.9040 - val_accuracy: 0.4071 - val_loss: 2.9893 - val_weighted_accuracy: 0.4071
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9138 - loss: 0.3650 - weighted_accuracy: 0.9138 - val_accuracy: 0.4690 - val_loss: 2.5001 - val_weighted_accuracy: 0.4690
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9030 - loss: 0.3988 - weighted_accuracy: 0.9030 - val_accuracy: 0.4599 - val_loss: 3.6693 - val_weighted_accuracy: 0.4599
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9202 - loss: 0.3561 - weighted_accuracy: 0.9202 - val_accuracy: 0.6284 - val_loss: 1.8666 - val_weighted_accuracy: 0.6284
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9217 - loss: 0.3677 - weighted_accuracy: 0.9217 - val_accuracy: 0.5817 - val_loss: 1.8186 - val_weighted_accuracy: 0.5817
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9204 - loss: 0.3380 - weighted_accuracy: 0.9204 - val_accuracy: 0.5401 - val_loss: 2.7384 - val_weighted_accuracy: 0.5401
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9232 - loss: 0.3562 - weighted_accuracy: 0.9232 - val_accuracy: 0.5827 - val_loss: 2.5883 - val_weighted_accuracy: 0.5827
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9362 - loss: 0.2868 - weighted_accuracy: 0.9362 - val_accuracy: 0.6213 - val_loss: 1.6925 - val_weighted_accuracy: 0.6213
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9266 - loss: 0.3287 - weighted_accuracy: 0.9266 - val_accuracy: 0.6690 - val_loss: 1.7538 - val_weighted_accuracy: 0.6690
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9225 - loss: 0.3406 - weighted_accuracy: 0.9225 - val_accuracy: 0.6822 - val_loss: 1.7359 - val_weighted_accuracy: 0.6822
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9357 - loss: 0.2996 - weighted_accuracy: 0.9357 - val_accuracy: 0.6609 - val_loss: 1.7213 - val_weighted_accuracy: 0.6609
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9355 - loss: 0.3070 - weighted_accuracy: 0.9355 - val_accuracy: 0.5635 - val_loss: 2.2079 - val_weighted_accuracy: 0.5635
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9440 - loss: 0.2867 - weighted_accuracy: 0.9440 - val_accuracy: 0.5726 - val_loss: 2.6330 - val_weighted_accuracy: 0.5726
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9369 - loss: 0.2974 - weighted_accuracy: 0.9369 - val_accuracy: 0.6234 - val_loss: 1.8717 - val_weighted_accuracy: 0.6234
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9509 - loss: 0.2499 - weighted_accuracy: 0.9509 - val_accuracy: 0.6761 - val_loss: 1.6430 - val_weighted_accuracy: 0.6761
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9457 - loss: 0.2610 - weighted_accuracy: 0.9457 - val_accuracy: 0.6670 - val_loss: 1.8433 - val_weighted_accuracy: 0.6670
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9369 - loss: 0.3027 - weighted_accuracy: 0.9369 - val_accuracy: 0.6629 - val_loss: 1.9397 - val_weighted_accuracy: 0.6629
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9487 - loss: 0.2505 - weighted_accuracy: 0.9487 - val_accuracy: 0.5990 - val_loss: 2.2507 - val_weighted_accuracy: 0.5990

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['all_features'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['all_features'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8850 - loss: 0.4185 - weighted_accuracy: 0.8850
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6366 - loss: 1.3563 - weighted_accuracy: 0.6366

# %% [markdown]
# ## **With Mel-Spectrogram, MFCCs, Chroma**

# %%
training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma']), axis=1)

print(training_features.shape)
# Out:
# (3954, 92, 259)

# %%
validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma']), axis=1)

print(validation_features.shape)
# Out:
# (985, 92, 259)

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=50
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 512)                 │       1,187,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │           1,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,363,156 (5.20 MB)
#  Trainable params: 1,362,132 (5.20 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.1340 - loss: 3.0477 - weighted_accuracy: 0.1340 - val_accuracy: 0.1168 - val_loss: 2.9965 - val_weighted_accuracy: 0.1168
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.3197 - loss: 2.2581 - weighted_accuracy: 0.3197 - val_accuracy: 0.0812 - val_loss: 2.7395 - val_weighted_accuracy: 0.0812
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.3777 - loss: 1.9596 - weighted_accuracy: 0.3777 - val_accuracy: 0.1635 - val_loss: 3.3620 - val_weighted_accuracy: 0.1635
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4149 - loss: 1.7621 - weighted_accuracy: 0.4149 - val_accuracy: 0.1898 - val_loss: 2.8515 - val_weighted_accuracy: 0.1898
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4571 - loss: 1.6477 - weighted_accuracy: 0.4571 - val_accuracy: 0.3787 - val_loss: 1.9925 - val_weighted_accuracy: 0.3787
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4911 - loss: 1.4979 - weighted_accuracy: 0.4911 - val_accuracy: 0.3157 - val_loss: 2.3989 - val_weighted_accuracy: 0.3157
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5077 - loss: 1.4209 - weighted_accuracy: 0.5077 - val_accuracy: 0.2711 - val_loss: 3.6619 - val_weighted_accuracy: 0.2711
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5584 - loss: 1.3081 - weighted_accuracy: 0.5584 - val_accuracy: 0.2904 - val_loss: 2.3708 - val_weighted_accuracy: 0.2904
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5914 - loss: 1.1974 - weighted_accuracy: 0.5914 - val_accuracy: 0.2518 - val_loss: 3.3008 - val_weighted_accuracy: 0.2518
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5986 - loss: 1.1919 - weighted_accuracy: 0.5986 - val_accuracy: 0.2213 - val_loss: 3.6478 - val_weighted_accuracy: 0.2213
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6325 - loss: 1.1137 - weighted_accuracy: 0.6325 - val_accuracy: 0.5147 - val_loss: 1.5732 - val_weighted_accuracy: 0.5147
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6521 - loss: 1.0618 - weighted_accuracy: 0.6521 - val_accuracy: 0.4457 - val_loss: 1.7292 - val_weighted_accuracy: 0.4457
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6613 - loss: 1.0565 - weighted_accuracy: 0.6613 - val_accuracy: 0.5371 - val_loss: 1.6250 - val_weighted_accuracy: 0.5371
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7017 - loss: 0.9252 - weighted_accuracy: 0.7017 - val_accuracy: 0.3421 - val_loss: 3.2374 - val_weighted_accuracy: 0.3421
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6882 - loss: 0.9279 - weighted_accuracy: 0.6882 - val_accuracy: 0.5117 - val_loss: 1.7932 - val_weighted_accuracy: 0.5117
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6941 - loss: 0.9131 - weighted_accuracy: 0.6941 - val_accuracy: 0.5523 - val_loss: 1.3332 - val_weighted_accuracy: 0.5523
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7503 - loss: 0.7738 - weighted_accuracy: 0.7503 - val_accuracy: 0.4487 - val_loss: 2.0501 - val_weighted_accuracy: 0.4487
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7610 - loss: 0.7425 - weighted_accuracy: 0.7610 - val_accuracy: 0.5076 - val_loss: 2.9338 - val_weighted_accuracy: 0.5076
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7632 - loss: 0.7575 - weighted_accuracy: 0.7632 - val_accuracy: 0.5015 - val_loss: 1.8612 - val_weighted_accuracy: 0.5015
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7742 - loss: 0.7256 - weighted_accuracy: 0.7742 - val_accuracy: 0.4112 - val_loss: 2.5899 - val_weighted_accuracy: 0.4112
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7797 - loss: 0.7493 - weighted_accuracy: 0.7797 - val_accuracy: 0.5695 - val_loss: 1.6281 - val_weighted_accuracy: 0.5695
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8083 - loss: 0.6108 - weighted_accuracy: 0.8083 - val_accuracy: 0.6051 - val_loss: 1.5147 - val_weighted_accuracy: 0.6051
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8290 - loss: 0.5815 - weighted_accuracy: 0.8290 - val_accuracy: 0.5015 - val_loss: 2.5673 - val_weighted_accuracy: 0.5015
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8359 - loss: 0.5791 - weighted_accuracy: 0.8359 - val_accuracy: 0.5188 - val_loss: 2.0641 - val_weighted_accuracy: 0.5188
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8337 - loss: 0.5497 - weighted_accuracy: 0.8337 - val_accuracy: 0.5431 - val_loss: 2.3659 - val_weighted_accuracy: 0.5431
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8418 - loss: 0.5523 - weighted_accuracy: 0.8418 - val_accuracy: 0.6041 - val_loss: 1.4019 - val_weighted_accuracy: 0.6041
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8567 - loss: 0.5077 - weighted_accuracy: 0.8567 - val_accuracy: 0.5492 - val_loss: 1.5312 - val_weighted_accuracy: 0.5492
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8665 - loss: 0.4888 - weighted_accuracy: 0.8665 - val_accuracy: 0.5604 - val_loss: 1.6732 - val_weighted_accuracy: 0.5604
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8698 - loss: 0.4751 - weighted_accuracy: 0.8698 - val_accuracy: 0.6589 - val_loss: 1.4025 - val_weighted_accuracy: 0.6589
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8620 - loss: 0.4797 - weighted_accuracy: 0.8620 - val_accuracy: 0.6406 - val_loss: 1.6228 - val_weighted_accuracy: 0.6406
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8932 - loss: 0.4260 - weighted_accuracy: 0.8932 - val_accuracy: 0.6223 - val_loss: 2.0298 - val_weighted_accuracy: 0.6223
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8941 - loss: 0.3891 - weighted_accuracy: 0.8941 - val_accuracy: 0.5036 - val_loss: 1.8203 - val_weighted_accuracy: 0.5036
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8976 - loss: 0.3795 - weighted_accuracy: 0.8976 - val_accuracy: 0.6386 - val_loss: 1.4537 - val_weighted_accuracy: 0.6386
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8989 - loss: 0.3812 - weighted_accuracy: 0.8989 - val_accuracy: 0.4975 - val_loss: 2.6138 - val_weighted_accuracy: 0.4975
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8935 - loss: 0.3753 - weighted_accuracy: 0.8935 - val_accuracy: 0.5401 - val_loss: 3.3065 - val_weighted_accuracy: 0.5401
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9096 - loss: 0.3684 - weighted_accuracy: 0.9096 - val_accuracy: 0.5543 - val_loss: 2.1829 - val_weighted_accuracy: 0.5543
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8982 - loss: 0.4340 - weighted_accuracy: 0.8982 - val_accuracy: 0.5848 - val_loss: 2.1649 - val_weighted_accuracy: 0.5848
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9083 - loss: 0.3730 - weighted_accuracy: 0.9083 - val_accuracy: 0.6528 - val_loss: 1.6898 - val_weighted_accuracy: 0.6528
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9332 - loss: 0.3005 - weighted_accuracy: 0.9332 - val_accuracy: 0.6751 - val_loss: 1.6743 - val_weighted_accuracy: 0.6751
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9312 - loss: 0.2944 - weighted_accuracy: 0.9312 - val_accuracy: 0.6345 - val_loss: 1.8726 - val_weighted_accuracy: 0.6345
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9343 - loss: 0.3004 - weighted_accuracy: 0.9343 - val_accuracy: 0.5756 - val_loss: 2.3035 - val_weighted_accuracy: 0.5756
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9284 - loss: 0.3226 - weighted_accuracy: 0.9284 - val_accuracy: 0.5888 - val_loss: 2.2935 - val_weighted_accuracy: 0.5888
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9313 - loss: 0.3192 - weighted_accuracy: 0.9313 - val_accuracy: 0.5706 - val_loss: 2.2734 - val_weighted_accuracy: 0.5706
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9451 - loss: 0.2726 - weighted_accuracy: 0.9451 - val_accuracy: 0.5025 - val_loss: 3.2181 - val_weighted_accuracy: 0.5025
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9440 - loss: 0.2587 - weighted_accuracy: 0.9440 - val_accuracy: 0.6213 - val_loss: 2.1121 - val_weighted_accuracy: 0.6213
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9443 - loss: 0.2715 - weighted_accuracy: 0.9443 - val_accuracy: 0.6640 - val_loss: 1.8016 - val_weighted_accuracy: 0.6640
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9370 - loss: 0.2993 - weighted_accuracy: 0.9370 - val_accuracy: 0.6274 - val_loss: 2.7889 - val_weighted_accuracy: 0.6274
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9447 - loss: 0.2766 - weighted_accuracy: 0.9447 - val_accuracy: 0.5523 - val_loss: 3.0666 - val_weighted_accuracy: 0.5523
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9509 - loss: 0.2716 - weighted_accuracy: 0.9509 - val_accuracy: 0.5472 - val_loss: 2.8055 - val_weighted_accuracy: 0.5472
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9468 - loss: 0.2631 - weighted_accuracy: 0.9468 - val_accuracy: 0.6670 - val_loss: 1.6765 - val_weighted_accuracy: 0.6670
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9614 - loss: 0.2325 - weighted_accuracy: 0.9614 - val_accuracy: 0.5411 - val_loss: 3.2176 - val_weighted_accuracy: 0.5411
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9535 - loss: 0.2489 - weighted_accuracy: 0.9535 - val_accuracy: 0.6772 - val_loss: 1.9315 - val_weighted_accuracy: 0.6772
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9508 - loss: 0.2590 - weighted_accuracy: 0.9508 - val_accuracy: 0.6142 - val_loss: 2.3208 - val_weighted_accuracy: 0.6142
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9517 - loss: 0.2494 - weighted_accuracy: 0.9517 - val_accuracy: 0.6365 - val_loss: 2.6993 - val_weighted_accuracy: 0.6365
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9443 - loss: 0.2968 - weighted_accuracy: 0.9443 - val_accuracy: 0.6497 - val_loss: 1.6769 - val_weighted_accuracy: 0.6497
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9559 - loss: 0.2359 - weighted_accuracy: 0.9559 - val_accuracy: 0.6487 - val_loss: 1.9235 - val_weighted_accuracy: 0.6487
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9679 - loss: 0.2050 - weighted_accuracy: 0.9679 - val_accuracy: 0.6020 - val_loss: 2.2313 - val_weighted_accuracy: 0.6020
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9589 - loss: 0.2325 - weighted_accuracy: 0.9589 - val_accuracy: 0.6365 - val_loss: 2.4834 - val_weighted_accuracy: 0.6365
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9620 - loss: 0.2191 - weighted_accuracy: 0.9620 - val_accuracy: 0.6193 - val_loss: 2.4439 - val_weighted_accuracy: 0.6193
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9632 - loss: 0.2194 - weighted_accuracy: 0.9632 - val_accuracy: 0.5949 - val_loss: 2.5170 - val_weighted_accuracy: 0.5949
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9624 - loss: 0.2160 - weighted_accuracy: 0.9624 - val_accuracy: 0.6193 - val_loss: 1.7276 - val_weighted_accuracy: 0.6193
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9608 - loss: 0.2289 - weighted_accuracy: 0.9608 - val_accuracy: 0.6355 - val_loss: 2.1675 - val_weighted_accuracy: 0.6355
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9578 - loss: 0.2443 - weighted_accuracy: 0.9578 - val_accuracy: 0.6406 - val_loss: 2.5633 - val_weighted_accuracy: 0.6406
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9555 - loss: 0.2432 - weighted_accuracy: 0.9555 - val_accuracy: 0.6538 - val_loss: 2.3492 - val_weighted_accuracy: 0.6538
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9646 - loss: 0.2292 - weighted_accuracy: 0.9646 - val_accuracy: 0.6761 - val_loss: 1.6567 - val_weighted_accuracy: 0.6761
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9536 - loss: 0.2618 - weighted_accuracy: 0.9536 - val_accuracy: 0.7005 - val_loss: 1.6905 - val_weighted_accuracy: 0.7005
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9619 - loss: 0.2231 - weighted_accuracy: 0.9619 - val_accuracy: 0.6487 - val_loss: 2.7419 - val_weighted_accuracy: 0.6487
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9656 - loss: 0.2222 - weighted_accuracy: 0.9656 - val_accuracy: 0.6751 - val_loss: 1.9657 - val_weighted_accuracy: 0.6751
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9619 - loss: 0.2498 - weighted_accuracy: 0.9619 - val_accuracy: 0.6497 - val_loss: 2.0767 - val_weighted_accuracy: 0.6497
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9695 - loss: 0.2397 - weighted_accuracy: 0.9695 - val_accuracy: 0.6761 - val_loss: 1.6360 - val_weighted_accuracy: 0.6761
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9664 - loss: 0.1969 - weighted_accuracy: 0.9664 - val_accuracy: 0.7025 - val_loss: 2.2149 - val_weighted_accuracy: 0.7025
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9767 - loss: 0.1791 - weighted_accuracy: 0.9767 - val_accuracy: 0.6569 - val_loss: 2.5776 - val_weighted_accuracy: 0.6569
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9727 - loss: 0.1994 - weighted_accuracy: 0.9727 - val_accuracy: 0.6305 - val_loss: 2.1378 - val_weighted_accuracy: 0.6305
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9785 - loss: 0.1516 - weighted_accuracy: 0.9785 - val_accuracy: 0.6315 - val_loss: 2.9038 - val_weighted_accuracy: 0.6315
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9838 - loss: 0.1530 - weighted_accuracy: 0.9838 - val_accuracy: 0.6893 - val_loss: 2.3401 - val_weighted_accuracy: 0.6893
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9778 - loss: 0.1786 - weighted_accuracy: 0.9778 - val_accuracy: 0.6599 - val_loss: 2.3720 - val_weighted_accuracy: 0.6599
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9689 - loss: 0.1955 - weighted_accuracy: 0.9689 - val_accuracy: 0.6914 - val_loss: 2.0079 - val_weighted_accuracy: 0.6914
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9818 - loss: 0.1631 - weighted_accuracy: 0.9818 - val_accuracy: 0.6122 - val_loss: 2.1687 - val_weighted_accuracy: 0.6122
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9728 - loss: 0.1808 - weighted_accuracy: 0.9728 - val_accuracy: 0.6640 - val_loss: 2.3353 - val_weighted_accuracy: 0.6640
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9782 - loss: 0.1693 - weighted_accuracy: 0.9782 - val_accuracy: 0.5807 - val_loss: 2.5234 - val_weighted_accuracy: 0.5807
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9775 - loss: 0.1647 - weighted_accuracy: 0.9775 - val_accuracy: 0.6406 - val_loss: 2.3247 - val_weighted_accuracy: 0.6406
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9723 - loss: 0.1901 - weighted_accuracy: 0.9723 - val_accuracy: 0.6051 - val_loss: 2.4663 - val_weighted_accuracy: 0.6051
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9807 - loss: 0.1585 - weighted_accuracy: 0.9807 - val_accuracy: 0.6619 - val_loss: 2.3533 - val_weighted_accuracy: 0.6619
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9846 - loss: 0.1514 - weighted_accuracy: 0.9846 - val_accuracy: 0.6609 - val_loss: 2.4014 - val_weighted_accuracy: 0.6609
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9889 - loss: 0.1372 - weighted_accuracy: 0.9889 - val_accuracy: 0.7015 - val_loss: 2.1421 - val_weighted_accuracy: 0.7015
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9722 - loss: 0.1801 - weighted_accuracy: 0.9722 - val_accuracy: 0.5858 - val_loss: 2.6573 - val_weighted_accuracy: 0.5858
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9731 - loss: 0.1968 - weighted_accuracy: 0.9731 - val_accuracy: 0.6711 - val_loss: 2.4148 - val_weighted_accuracy: 0.6711
# Epoch 88/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9818 - loss: 0.1609 - weighted_accuracy: 0.9818 - val_accuracy: 0.6609 - val_loss: 2.4864 - val_weighted_accuracy: 0.6609
# Epoch 89/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9783 - loss: 0.1777 - weighted_accuracy: 0.9783 - val_accuracy: 0.6508 - val_loss: 2.7040 - val_weighted_accuracy: 0.6508
# Epoch 90/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9745 - loss: 0.1992 - weighted_accuracy: 0.9745 - val_accuracy: 0.6335 - val_loss: 2.6673 - val_weighted_accuracy: 0.6335

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['melspectrogram_chroma_mfcc'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['melspectrogram_chroma_mfcc'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9838 - loss: 0.1486 - weighted_accuracy: 0.9838
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6735 - loss: 1.6883 - weighted_accuracy: 0.6735

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(3)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(3)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Features')
result_df
# Out:
#                      Features  Train_Accuracy  Val_Accuracy
# 0                all_features           0.890         0.657
# 1  melspectrogram_chroma_mfcc           0.981         0.676
