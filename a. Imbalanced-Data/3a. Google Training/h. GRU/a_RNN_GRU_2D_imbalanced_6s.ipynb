# %% [markdown]
# # **CNN**
# - Using data that was not annotated
# - Training it on the unbalanced data
# - Using avgpool
# - 6 second window

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard libraries
import numpy as np
import pandas as pd
import time
import os

# For audio
from IPython.display import Audio
import librosa

# For preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# For modeling
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Operational
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.ndimage
import pygame
import time
from scipy.signal import butter, filtfilt
import random
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pkl_path = '/content/drive/My Drive/Final-Year-Project/Dataset/Project-V4/feature-extraction/Annotated/NotAveragePooled/split_features_6s_all.pkl'

# Load the pickle file
with open(pkl_path, 'rb') as file:
    data = pickle.load(file)

# %%
train_data = data['train'].copy()
val_data = data['val'].copy()

# %%
# train_data]

# %%
train_labels = train_data['label'].copy()
temp = train_data.copy()
del temp['label']
tr_features = temp

# %%
val_labels = val_data['label'].copy()
temp = val_data.copy()
del temp['label']
v_features = temp

# %% [markdown]
# # Shuffle Data

# %%
def shuffle_data(input_label, input_features):
  input_len = len(input_label)
  np.random.seed(1826)
  input_indices = np.random.permutation(input_len)
  input_features = {key: np.array([input_features[key][i] for i in input_indices]) for key in input_features} # dictionary comprehension
  input_label = np.array([input_label[i] for i in input_indices])

  return input_label, input_features

# %%
train_y, train_features = shuffle_data(train_labels, tr_features)

# %%
val_y, val_features = shuffle_data(val_labels, v_features)

# %%
# display(train_y.shape)
# display(train_y[:15])

# %%
# for key in train_features.keys():
#   display(key)
#   display(train_features[key].shape)
#   display(train_features[key][0])

# %%
# display(val_y.shape)
# display(val_y[:15])

# %%
# for key in val_features.keys():
#   display(key)
#   display(val_features[key].shape)
#   display(val_features[key][0])

# %% [markdown]
# ## **LSTM Model**

# %%
def build_model(audio_features,
                learning_rate=0.0002,
                gru=256,
                hidden=[256,128,48],
                dropout=0.3):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # add sequential model
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.GRU(gru, input_shape=(audio_features.shape[1],audio_features.shape[2])))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(dropout))

  for size in hidden:
    model.add(tf.keras.layers.Dense(size, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    model.add(tf.keras.layers.Dropout(dropout))

  model.add(tf.keras.layers.Dense(units=20,activation='softmax'))

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Visualize the loss
    axes[0].plot(model_history.history['loss'], color='red', label='Training Loss')
    axes[0].plot(model_history.history['val_loss'], color='blue', label='Validation Loss')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss Progression', fontsize=14)
    axes[0].grid(True)
    axes[0].legend()

    # Visualize the accuracy
    axes[1].plot(model_history.history['accuracy'], color='green', label='Training Accuracy')
    axes[1].plot(model_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Accuracy Progression', fontsize=14)
    axes[1].grid(True)
    axes[1].legend()

    # Fine-tune layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
train_results = {}
val_results = {}

# %% [markdown]
# ### **With all the features**

# %%
# n_time = train_features['melspectrogram'].shape[2]

# mfcc_tiled = np.tile(train_features['mfcc'], (1, 3, 1))  # (3318, 60, 44), tiling 3 times to match 60 features
# chroma_tiled = np.tile(train_features['chroma'], (1, 5, 1))  # (3318, 60, 44), tiling 5 times to match 60 features
# rms_tiled = np.tile(train_features['rms'], (1, 60, 1))  # (3318, 60, 44), tiling 60 times to match 60 features

training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma'], train_features['rms']), axis=1)

print(training_features.shape)
# Out:
# (3954, 93, 259)

# %%
# mfcc_val_tiled = np.tile(val_features['mfcc'], (1, 3, 1))  # Tile to (n_samples_val, 60, 44)
# chroma_val_tiled = np.tile(val_features['chroma'], (1, 5, 1))  # Tile to (n_samples_val, 60, 44)
# rms_val_tiled = np.tile(val_features['rms'], (1, 60, 1))  # Tile to (n_samples_val, 60, 44)

# melspectrogram_val = val_features['melspectrogram']

validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma'], val_features['rms']), axis=1)

print(validation_features.shape)
# Out:
# (985, 93, 259)

# %% [markdown]
# Fit the model with training data

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 48)                  │           6,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 48)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             980 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 503,940 (1.92 MB)
#  Trainable params: 503,428 (1.92 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0811 - loss: 7.9516 - weighted_accuracy: 0.0811 - val_accuracy: 0.1015 - val_loss: 7.4778 - val_weighted_accuracy: 0.1015
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1836 - loss: 7.1120 - weighted_accuracy: 0.1836 - val_accuracy: 0.2467 - val_loss: 6.8440 - val_weighted_accuracy: 0.2467
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2369 - loss: 6.5447 - weighted_accuracy: 0.2369 - val_accuracy: 0.2335 - val_loss: 6.2357 - val_weighted_accuracy: 0.2335
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2559 - loss: 6.0239 - weighted_accuracy: 0.2559 - val_accuracy: 0.2548 - val_loss: 5.7197 - val_weighted_accuracy: 0.2548
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2862 - loss: 5.5389 - weighted_accuracy: 0.2862 - val_accuracy: 0.3421 - val_loss: 5.1881 - val_weighted_accuracy: 0.3421
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3058 - loss: 5.1169 - weighted_accuracy: 0.3058 - val_accuracy: 0.3553 - val_loss: 4.7649 - val_weighted_accuracy: 0.3553
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3526 - loss: 4.7301 - weighted_accuracy: 0.3526 - val_accuracy: 0.3645 - val_loss: 4.4333 - val_weighted_accuracy: 0.3645
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3884 - loss: 4.3553 - weighted_accuracy: 0.3884 - val_accuracy: 0.3168 - val_loss: 4.3055 - val_weighted_accuracy: 0.3168
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3769 - loss: 4.0633 - weighted_accuracy: 0.3769 - val_accuracy: 0.4203 - val_loss: 3.8816 - val_weighted_accuracy: 0.4203
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4113 - loss: 3.7476 - weighted_accuracy: 0.4113 - val_accuracy: 0.3543 - val_loss: 3.8267 - val_weighted_accuracy: 0.3543
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4332 - loss: 3.5024 - weighted_accuracy: 0.4332 - val_accuracy: 0.4223 - val_loss: 3.5244 - val_weighted_accuracy: 0.4223
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4459 - loss: 3.2520 - weighted_accuracy: 0.4459 - val_accuracy: 0.3878 - val_loss: 3.4713 - val_weighted_accuracy: 0.3878
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4903 - loss: 3.0175 - weighted_accuracy: 0.4903 - val_accuracy: 0.4640 - val_loss: 3.0696 - val_weighted_accuracy: 0.4640
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4995 - loss: 2.8269 - weighted_accuracy: 0.4995 - val_accuracy: 0.4315 - val_loss: 3.0234 - val_weighted_accuracy: 0.4315
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5209 - loss: 2.6659 - weighted_accuracy: 0.5209 - val_accuracy: 0.3117 - val_loss: 3.7116 - val_weighted_accuracy: 0.3117
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5405 - loss: 2.5194 - weighted_accuracy: 0.5405 - val_accuracy: 0.4234 - val_loss: 2.9355 - val_weighted_accuracy: 0.4234
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5636 - loss: 2.3221 - weighted_accuracy: 0.5636 - val_accuracy: 0.5036 - val_loss: 2.5186 - val_weighted_accuracy: 0.5036
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5753 - loss: 2.2195 - weighted_accuracy: 0.5753 - val_accuracy: 0.4599 - val_loss: 2.6003 - val_weighted_accuracy: 0.4599
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5855 - loss: 2.1330 - weighted_accuracy: 0.5855 - val_accuracy: 0.4995 - val_loss: 2.4639 - val_weighted_accuracy: 0.4995
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6010 - loss: 1.9925 - weighted_accuracy: 0.6010 - val_accuracy: 0.4193 - val_loss: 2.6174 - val_weighted_accuracy: 0.4193
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6109 - loss: 1.9518 - weighted_accuracy: 0.6109 - val_accuracy: 0.4406 - val_loss: 2.8906 - val_weighted_accuracy: 0.4406
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6301 - loss: 1.8230 - weighted_accuracy: 0.6301 - val_accuracy: 0.4487 - val_loss: 2.4894 - val_weighted_accuracy: 0.4487
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6339 - loss: 1.7897 - weighted_accuracy: 0.6339 - val_accuracy: 0.4579 - val_loss: 2.4837 - val_weighted_accuracy: 0.4579
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6542 - loss: 1.6880 - weighted_accuracy: 0.6542 - val_accuracy: 0.4721 - val_loss: 2.3956 - val_weighted_accuracy: 0.4721
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6477 - loss: 1.6718 - weighted_accuracy: 0.6477 - val_accuracy: 0.4223 - val_loss: 2.5099 - val_weighted_accuracy: 0.4223
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6521 - loss: 1.5884 - weighted_accuracy: 0.6521 - val_accuracy: 0.5198 - val_loss: 2.0905 - val_weighted_accuracy: 0.5198
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6857 - loss: 1.5112 - weighted_accuracy: 0.6857 - val_accuracy: 0.4843 - val_loss: 2.2213 - val_weighted_accuracy: 0.4843
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6877 - loss: 1.4646 - weighted_accuracy: 0.6877 - val_accuracy: 0.4477 - val_loss: 2.7825 - val_weighted_accuracy: 0.4477
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6954 - loss: 1.4413 - weighted_accuracy: 0.6954 - val_accuracy: 0.4315 - val_loss: 2.4241 - val_weighted_accuracy: 0.4315
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7087 - loss: 1.3674 - weighted_accuracy: 0.7087 - val_accuracy: 0.4812 - val_loss: 2.2929 - val_weighted_accuracy: 0.4812
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7140 - loss: 1.3443 - weighted_accuracy: 0.7140 - val_accuracy: 0.4335 - val_loss: 2.4206 - val_weighted_accuracy: 0.4335
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7109 - loss: 1.3410 - weighted_accuracy: 0.7109 - val_accuracy: 0.4315 - val_loss: 2.5382 - val_weighted_accuracy: 0.4315
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7398 - loss: 1.2678 - weighted_accuracy: 0.7398 - val_accuracy: 0.4812 - val_loss: 2.3085 - val_weighted_accuracy: 0.4812
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7375 - loss: 1.2455 - weighted_accuracy: 0.7375 - val_accuracy: 0.5086 - val_loss: 2.2184 - val_weighted_accuracy: 0.5086
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7536 - loss: 1.2008 - weighted_accuracy: 0.7536 - val_accuracy: 0.4193 - val_loss: 2.5962 - val_weighted_accuracy: 0.4193
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7699 - loss: 1.1479 - weighted_accuracy: 0.7699 - val_accuracy: 0.4396 - val_loss: 2.7591 - val_weighted_accuracy: 0.4396
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7724 - loss: 1.1488 - weighted_accuracy: 0.7724 - val_accuracy: 0.5218 - val_loss: 2.1430 - val_weighted_accuracy: 0.5218
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7801 - loss: 1.0963 - weighted_accuracy: 0.7801 - val_accuracy: 0.5046 - val_loss: 2.2399 - val_weighted_accuracy: 0.5046
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7796 - loss: 1.0904 - weighted_accuracy: 0.7796 - val_accuracy: 0.4447 - val_loss: 2.6461 - val_weighted_accuracy: 0.4447
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7859 - loss: 1.0879 - weighted_accuracy: 0.7859 - val_accuracy: 0.4234 - val_loss: 2.8328 - val_weighted_accuracy: 0.4234
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7972 - loss: 1.0389 - weighted_accuracy: 0.7972 - val_accuracy: 0.4609 - val_loss: 2.4009 - val_weighted_accuracy: 0.4609
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8157 - loss: 0.9916 - weighted_accuracy: 0.8157 - val_accuracy: 0.4741 - val_loss: 2.3293 - val_weighted_accuracy: 0.4741
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8002 - loss: 0.9989 - weighted_accuracy: 0.8002 - val_accuracy: 0.4883 - val_loss: 2.4685 - val_weighted_accuracy: 0.4883
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8089 - loss: 0.9804 - weighted_accuracy: 0.8089 - val_accuracy: 0.4619 - val_loss: 2.7831 - val_weighted_accuracy: 0.4619
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8085 - loss: 0.9615 - weighted_accuracy: 0.8085 - val_accuracy: 0.4244 - val_loss: 2.6939 - val_weighted_accuracy: 0.4244
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8217 - loss: 0.9193 - weighted_accuracy: 0.8217 - val_accuracy: 0.5482 - val_loss: 2.1044 - val_weighted_accuracy: 0.5482

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['all_features'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['all_features'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7440 - loss: 1.3067 - weighted_accuracy: 0.7440
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4904 - loss: 2.1711 - weighted_accuracy: 0.4904

# %% [markdown]
# ## **With Mel-Spectrogram, MFCCs, Chroma**

# %%
training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma']), axis=1)

print(training_features.shape)
# Out:
# (3954, 92, 259)

# %%
validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma']), axis=1)

print(validation_features.shape)
# Out:
# (985, 92, 259)

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=50
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 48)                  │           6,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 48)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             980 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 503,940 (1.92 MB)
#  Trainable params: 503,428 (1.92 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0939 - loss: 8.0321 - weighted_accuracy: 0.0939 - val_accuracy: 0.1005 - val_loss: 7.4688 - val_weighted_accuracy: 0.1005
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1724 - loss: 7.1755 - weighted_accuracy: 0.1724 - val_accuracy: 0.1970 - val_loss: 6.8801 - val_weighted_accuracy: 0.1970
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2043 - loss: 6.6036 - weighted_accuracy: 0.2043 - val_accuracy: 0.2538 - val_loss: 6.2115 - val_weighted_accuracy: 0.2538
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2412 - loss: 6.1357 - weighted_accuracy: 0.2412 - val_accuracy: 0.2944 - val_loss: 5.7278 - val_weighted_accuracy: 0.2944
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2788 - loss: 5.7054 - weighted_accuracy: 0.2788 - val_accuracy: 0.2843 - val_loss: 5.3582 - val_weighted_accuracy: 0.2843
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2903 - loss: 5.2779 - weighted_accuracy: 0.2903 - val_accuracy: 0.3127 - val_loss: 4.9155 - val_weighted_accuracy: 0.3127
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3153 - loss: 4.9094 - weighted_accuracy: 0.3153 - val_accuracy: 0.3442 - val_loss: 4.5973 - val_weighted_accuracy: 0.3442
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3199 - loss: 4.5752 - weighted_accuracy: 0.3199 - val_accuracy: 0.3492 - val_loss: 4.3702 - val_weighted_accuracy: 0.3492
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3363 - loss: 4.2683 - weighted_accuracy: 0.3363 - val_accuracy: 0.3228 - val_loss: 4.1143 - val_weighted_accuracy: 0.3228
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3742 - loss: 3.9450 - weighted_accuracy: 0.3742 - val_accuracy: 0.3635 - val_loss: 3.8292 - val_weighted_accuracy: 0.3635
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3781 - loss: 3.7357 - weighted_accuracy: 0.3781 - val_accuracy: 0.3695 - val_loss: 3.6236 - val_weighted_accuracy: 0.3695
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3995 - loss: 3.4696 - weighted_accuracy: 0.3995 - val_accuracy: 0.3198 - val_loss: 3.5140 - val_weighted_accuracy: 0.3198
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4219 - loss: 3.2529 - weighted_accuracy: 0.4219 - val_accuracy: 0.3096 - val_loss: 3.6400 - val_weighted_accuracy: 0.3096
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4131 - loss: 3.0866 - weighted_accuracy: 0.4131 - val_accuracy: 0.3523 - val_loss: 3.1657 - val_weighted_accuracy: 0.3523
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4430 - loss: 2.9273 - weighted_accuracy: 0.4430 - val_accuracy: 0.3858 - val_loss: 2.9887 - val_weighted_accuracy: 0.3858
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4682 - loss: 2.7468 - weighted_accuracy: 0.4682 - val_accuracy: 0.3868 - val_loss: 2.8886 - val_weighted_accuracy: 0.3868
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4965 - loss: 2.5739 - weighted_accuracy: 0.4965 - val_accuracy: 0.3695 - val_loss: 2.9397 - val_weighted_accuracy: 0.3695
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4970 - loss: 2.4412 - weighted_accuracy: 0.4970 - val_accuracy: 0.3827 - val_loss: 2.8300 - val_weighted_accuracy: 0.3827
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5024 - loss: 2.3863 - weighted_accuracy: 0.5024 - val_accuracy: 0.4173 - val_loss: 2.6179 - val_weighted_accuracy: 0.4173
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5440 - loss: 2.2082 - weighted_accuracy: 0.5440 - val_accuracy: 0.3645 - val_loss: 2.8665 - val_weighted_accuracy: 0.3645
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5609 - loss: 2.1080 - weighted_accuracy: 0.5609 - val_accuracy: 0.3990 - val_loss: 2.5855 - val_weighted_accuracy: 0.3990
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5686 - loss: 2.0278 - weighted_accuracy: 0.5686 - val_accuracy: 0.4132 - val_loss: 2.6331 - val_weighted_accuracy: 0.4132
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5732 - loss: 1.9706 - weighted_accuracy: 0.5732 - val_accuracy: 0.4670 - val_loss: 2.4751 - val_weighted_accuracy: 0.4670
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5924 - loss: 1.8324 - weighted_accuracy: 0.5924 - val_accuracy: 0.4355 - val_loss: 2.5048 - val_weighted_accuracy: 0.4355
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6004 - loss: 1.8024 - weighted_accuracy: 0.6004 - val_accuracy: 0.3797 - val_loss: 2.7649 - val_weighted_accuracy: 0.3797
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6150 - loss: 1.7291 - weighted_accuracy: 0.6150 - val_accuracy: 0.4162 - val_loss: 2.4066 - val_weighted_accuracy: 0.4162
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6408 - loss: 1.6372 - weighted_accuracy: 0.6408 - val_accuracy: 0.4152 - val_loss: 2.4710 - val_weighted_accuracy: 0.4152
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6366 - loss: 1.6072 - weighted_accuracy: 0.6366 - val_accuracy: 0.4650 - val_loss: 2.2312 - val_weighted_accuracy: 0.4650
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6433 - loss: 1.5688 - weighted_accuracy: 0.6433 - val_accuracy: 0.4386 - val_loss: 2.3964 - val_weighted_accuracy: 0.4386
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6683 - loss: 1.4790 - weighted_accuracy: 0.6683 - val_accuracy: 0.4538 - val_loss: 2.4157 - val_weighted_accuracy: 0.4538
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6738 - loss: 1.4463 - weighted_accuracy: 0.6738 - val_accuracy: 0.4650 - val_loss: 2.2954 - val_weighted_accuracy: 0.4650
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6943 - loss: 1.3634 - weighted_accuracy: 0.6943 - val_accuracy: 0.4335 - val_loss: 2.2756 - val_weighted_accuracy: 0.4335
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7238 - loss: 1.3011 - weighted_accuracy: 0.7238 - val_accuracy: 0.5117 - val_loss: 2.0136 - val_weighted_accuracy: 0.5117
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7114 - loss: 1.3055 - weighted_accuracy: 0.7114 - val_accuracy: 0.5208 - val_loss: 1.8757 - val_weighted_accuracy: 0.5208
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7398 - loss: 1.2192 - weighted_accuracy: 0.7398 - val_accuracy: 0.4701 - val_loss: 2.2047 - val_weighted_accuracy: 0.4701
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7224 - loss: 1.2353 - weighted_accuracy: 0.7224 - val_accuracy: 0.5371 - val_loss: 1.9609 - val_weighted_accuracy: 0.5371
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7573 - loss: 1.1401 - weighted_accuracy: 0.7573 - val_accuracy: 0.5025 - val_loss: 2.0627 - val_weighted_accuracy: 0.5025
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7620 - loss: 1.1440 - weighted_accuracy: 0.7620 - val_accuracy: 0.4802 - val_loss: 2.1561 - val_weighted_accuracy: 0.4802
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7561 - loss: 1.1166 - weighted_accuracy: 0.7561 - val_accuracy: 0.4893 - val_loss: 2.0501 - val_weighted_accuracy: 0.4893
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7753 - loss: 1.1054 - weighted_accuracy: 0.7753 - val_accuracy: 0.5350 - val_loss: 2.0462 - val_weighted_accuracy: 0.5350
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7840 - loss: 1.0720 - weighted_accuracy: 0.7840 - val_accuracy: 0.4365 - val_loss: 2.5195 - val_weighted_accuracy: 0.4365
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7676 - loss: 1.0728 - weighted_accuracy: 0.7676 - val_accuracy: 0.4548 - val_loss: 2.4757 - val_weighted_accuracy: 0.4548
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7920 - loss: 1.0103 - weighted_accuracy: 0.7920 - val_accuracy: 0.5056 - val_loss: 2.0965 - val_weighted_accuracy: 0.5056
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7995 - loss: 0.9825 - weighted_accuracy: 0.7995 - val_accuracy: 0.4112 - val_loss: 2.7806 - val_weighted_accuracy: 0.4112
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8092 - loss: 0.9468 - weighted_accuracy: 0.8092 - val_accuracy: 0.5371 - val_loss: 1.9415 - val_weighted_accuracy: 0.5371
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8146 - loss: 0.9377 - weighted_accuracy: 0.8146 - val_accuracy: 0.5421 - val_loss: 2.0905 - val_weighted_accuracy: 0.5421
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8165 - loss: 0.9229 - weighted_accuracy: 0.8165 - val_accuracy: 0.5320 - val_loss: 2.1843 - val_weighted_accuracy: 0.5320
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8178 - loss: 0.8935 - weighted_accuracy: 0.8178 - val_accuracy: 0.4711 - val_loss: 2.4328 - val_weighted_accuracy: 0.4711
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8215 - loss: 0.8880 - weighted_accuracy: 0.8215 - val_accuracy: 0.4964 - val_loss: 2.0992 - val_weighted_accuracy: 0.4964
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8226 - loss: 0.8783 - weighted_accuracy: 0.8226 - val_accuracy: 0.5421 - val_loss: 1.9296 - val_weighted_accuracy: 0.5421
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8447 - loss: 0.8135 - weighted_accuracy: 0.8447 - val_accuracy: 0.4416 - val_loss: 2.9098 - val_weighted_accuracy: 0.4416
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8330 - loss: 0.8743 - weighted_accuracy: 0.8330 - val_accuracy: 0.4904 - val_loss: 2.2779 - val_weighted_accuracy: 0.4904
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8682 - loss: 0.7680 - weighted_accuracy: 0.8682 - val_accuracy: 0.5157 - val_loss: 2.4582 - val_weighted_accuracy: 0.5157
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8394 - loss: 0.8050 - weighted_accuracy: 0.8394 - val_accuracy: 0.4893 - val_loss: 2.4543 - val_weighted_accuracy: 0.4893
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8473 - loss: 0.8024 - weighted_accuracy: 0.8473 - val_accuracy: 0.5137 - val_loss: 2.3502 - val_weighted_accuracy: 0.5137
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8636 - loss: 0.7622 - weighted_accuracy: 0.8636 - val_accuracy: 0.5289 - val_loss: 2.2540 - val_weighted_accuracy: 0.5289
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8758 - loss: 0.7402 - weighted_accuracy: 0.8758 - val_accuracy: 0.5036 - val_loss: 2.2554 - val_weighted_accuracy: 0.5036
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8793 - loss: 0.7120 - weighted_accuracy: 0.8793 - val_accuracy: 0.5482 - val_loss: 2.1833 - val_weighted_accuracy: 0.5482
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8758 - loss: 0.7084 - weighted_accuracy: 0.8758 - val_accuracy: 0.4579 - val_loss: 2.8897 - val_weighted_accuracy: 0.4579
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8795 - loss: 0.6881 - weighted_accuracy: 0.8795 - val_accuracy: 0.5178 - val_loss: 2.2327 - val_weighted_accuracy: 0.5178
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8966 - loss: 0.6573 - weighted_accuracy: 0.8966 - val_accuracy: 0.5289 - val_loss: 2.2798 - val_weighted_accuracy: 0.5289
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8915 - loss: 0.6613 - weighted_accuracy: 0.8915 - val_accuracy: 0.5777 - val_loss: 2.2339 - val_weighted_accuracy: 0.5777
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8740 - loss: 0.6772 - weighted_accuracy: 0.8740 - val_accuracy: 0.5330 - val_loss: 2.3594 - val_weighted_accuracy: 0.5330
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8981 - loss: 0.6293 - weighted_accuracy: 0.8981 - val_accuracy: 0.5513 - val_loss: 2.0867 - val_weighted_accuracy: 0.5513
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8932 - loss: 0.6555 - weighted_accuracy: 0.8932 - val_accuracy: 0.5086 - val_loss: 2.4961 - val_weighted_accuracy: 0.5086
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8936 - loss: 0.6423 - weighted_accuracy: 0.8936 - val_accuracy: 0.5462 - val_loss: 2.2683 - val_weighted_accuracy: 0.5462
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8939 - loss: 0.6407 - weighted_accuracy: 0.8939 - val_accuracy: 0.5827 - val_loss: 2.0623 - val_weighted_accuracy: 0.5827
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9147 - loss: 0.5775 - weighted_accuracy: 0.9147 - val_accuracy: 0.4893 - val_loss: 2.9288 - val_weighted_accuracy: 0.4893
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9114 - loss: 0.5804 - weighted_accuracy: 0.9114 - val_accuracy: 0.5421 - val_loss: 2.3013 - val_weighted_accuracy: 0.5421
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9164 - loss: 0.5631 - weighted_accuracy: 0.9164 - val_accuracy: 0.5360 - val_loss: 2.4212 - val_weighted_accuracy: 0.5360
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9055 - loss: 0.5813 - weighted_accuracy: 0.9055 - val_accuracy: 0.5005 - val_loss: 2.5703 - val_weighted_accuracy: 0.5005
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9188 - loss: 0.5544 - weighted_accuracy: 0.9188 - val_accuracy: 0.4274 - val_loss: 3.0227 - val_weighted_accuracy: 0.4274
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9057 - loss: 0.5830 - weighted_accuracy: 0.9057 - val_accuracy: 0.5624 - val_loss: 2.2255 - val_weighted_accuracy: 0.5624
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9063 - loss: 0.5753 - weighted_accuracy: 0.9063 - val_accuracy: 0.5015 - val_loss: 2.4028 - val_weighted_accuracy: 0.5015
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9237 - loss: 0.5193 - weighted_accuracy: 0.9237 - val_accuracy: 0.5513 - val_loss: 2.2637 - val_weighted_accuracy: 0.5513
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9150 - loss: 0.5562 - weighted_accuracy: 0.9150 - val_accuracy: 0.5259 - val_loss: 2.3193 - val_weighted_accuracy: 0.5259
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9293 - loss: 0.5147 - weighted_accuracy: 0.9293 - val_accuracy: 0.5330 - val_loss: 2.7726 - val_weighted_accuracy: 0.5330
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9315 - loss: 0.5013 - weighted_accuracy: 0.9315 - val_accuracy: 0.5492 - val_loss: 2.3846 - val_weighted_accuracy: 0.5492
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9307 - loss: 0.5145 - weighted_accuracy: 0.9307 - val_accuracy: 0.5157 - val_loss: 2.6244 - val_weighted_accuracy: 0.5157
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9161 - loss: 0.5297 - weighted_accuracy: 0.9161 - val_accuracy: 0.5421 - val_loss: 2.3901 - val_weighted_accuracy: 0.5421
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9274 - loss: 0.5073 - weighted_accuracy: 0.9274 - val_accuracy: 0.5401 - val_loss: 2.3856 - val_weighted_accuracy: 0.5401
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9319 - loss: 0.4931 - weighted_accuracy: 0.9319 - val_accuracy: 0.5604 - val_loss: 2.2196 - val_weighted_accuracy: 0.5604
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9328 - loss: 0.4977 - weighted_accuracy: 0.9328 - val_accuracy: 0.5503 - val_loss: 2.4970 - val_weighted_accuracy: 0.5503
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9174 - loss: 0.5351 - weighted_accuracy: 0.9174 - val_accuracy: 0.5827 - val_loss: 2.1019 - val_weighted_accuracy: 0.5827
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9422 - loss: 0.4588 - weighted_accuracy: 0.9422 - val_accuracy: 0.5584 - val_loss: 2.2562 - val_weighted_accuracy: 0.5584
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9406 - loss: 0.4632 - weighted_accuracy: 0.9406 - val_accuracy: 0.5777 - val_loss: 2.0991 - val_weighted_accuracy: 0.5777
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9462 - loss: 0.4462 - weighted_accuracy: 0.9462 - val_accuracy: 0.5817 - val_loss: 2.1336 - val_weighted_accuracy: 0.5817

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['melspectrogram_chroma_mfcc'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['melspectrogram_chroma_mfcc'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9259 - loss: 0.5281 - weighted_accuracy: 0.9259
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5578 - loss: 2.1749 - weighted_accuracy: 0.5578

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(3)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(3)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Features')
result_df
# Out:
#                      Features  Train_Accuracy  Val_Accuracy
# 0                all_features           0.751         0.520
# 1  melspectrogram_chroma_mfcc           0.927         0.583
