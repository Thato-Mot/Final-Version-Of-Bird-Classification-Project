# %% [markdown]
# # **CNN**
# - Using data that was not annotated
# - Training it on the unbalanced data
# - Using avgpool
# - 6 second window

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard libraries
import numpy as np
import pandas as pd
import time
import os

# For audio
from IPython.display import Audio
import librosa

# For preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# For modeling
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Operational
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.ndimage
import pygame
import time
from scipy.signal import butter, filtfilt
import random
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pkl_path = '/content/drive/My Drive/Final-Year-Project/Dataset/Project-V4/feature-extraction/Annotated/NotAveragePooled/split_features_6s_all.pkl'

# Load the pickle file
with open(pkl_path, 'rb') as file:
    data = pickle.load(file)

# %%
train_data = data['train'].copy()
val_data = data['val'].copy()

# %%
# train_data]

# %%
train_labels = train_data['label'].copy()
temp = train_data.copy()
del temp['label']
tr_features = temp

# %%
val_labels = val_data['label'].copy()
temp = val_data.copy()
del temp['label']
v_features = temp

# %% [markdown]
# # Shuffle Data

# %%
def shuffle_data(input_label, input_features):
  input_len = len(input_label)
  np.random.seed(1826)
  input_indices = np.random.permutation(input_len)
  input_features = {key: np.array([input_features[key][i] for i in input_indices]) for key in input_features} # dictionary comprehension
  input_label = np.array([input_label[i] for i in input_indices])

  return input_label, input_features

# %%
train_y, train_features = shuffle_data(train_labels, tr_features)

# %%
val_y, val_features = shuffle_data(val_labels, v_features)

# %% [markdown]
# ## **LSTM Model**

# %%
def build_model(audio_features,
                learning_rate=0.001,
                gru=256,
                hidden=[128,128,32],
                dropout=0.2):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # add sequential model
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.GRU(gru, input_shape=(audio_features.shape[1],audio_features.shape[2])))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(dropout))

  for size in hidden:
    model.add(tf.keras.layers.Dense(size, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.005)))
    model.add(tf.keras.layers.Dropout(dropout))

  model.add(tf.keras.layers.Dense(units=20,activation='softmax'))

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Visualize the loss
    axes[0].plot(model_history.history['loss'], color='red', label='Training Loss')
    axes[0].plot(model_history.history['val_loss'], color='blue', label='Validation Loss')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss Progression', fontsize=14)
    axes[0].grid(True)
    axes[0].legend()

    # Visualize the accuracy
    axes[1].plot(model_history.history['accuracy'], color='green', label='Training Accuracy')
    axes[1].plot(model_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Accuracy Progression', fontsize=14)
    axes[1].grid(True)
    axes[1].legend()

    # Fine-tune layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
train_results = {}
val_results = {}

# %% [markdown]
# ### **With all the features**

# %%
# n_time = train_features['melspectrogram'].shape[2]

# mfcc_tiled = np.tile(train_features['mfcc'], (1, 3, 1))  # (3318, 60, 44), tiling 3 times to match 60 features
# chroma_tiled = np.tile(train_features['chroma'], (1, 5, 1))  # (3318, 60, 44), tiling 5 times to match 60 features
# rms_tiled = np.tile(train_features['rms'], (1, 60, 1))  # (3318, 60, 44), tiling 60 times to match 60 features

training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma'], train_features['rms']), axis=1)

print(training_features.shape)
# Out:
# (3954, 93, 259)

# %%
# mfcc_val_tiled = np.tile(val_features['mfcc'], (1, 3, 1))  # Tile to (n_samples_val, 60, 44)
# chroma_val_tiled = np.tile(val_features['chroma'], (1, 5, 1))  # Tile to (n_samples_val, 60, 44)
# rms_val_tiled = np.tile(val_features['rms'], (1, 60, 1))  # Tile to (n_samples_val, 60, 44)

# melspectrogram_val = val_features['melspectrogram']

validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma'], val_features['rms']), axis=1)

print(validation_features.shape)
# Out:
# (985, 93, 259)

# %% [markdown]
# Fit the model with training data

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=90
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             660 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 452,276 (1.73 MB)
#  Trainable params: 451,764 (1.72 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.1767 - loss: 4.3363 - weighted_accuracy: 0.1767 - val_accuracy: 0.2142 - val_loss: 4.0513 - val_weighted_accuracy: 0.2142
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3352 - loss: 3.3929 - weighted_accuracy: 0.3352 - val_accuracy: 0.2609 - val_loss: 3.5293 - val_weighted_accuracy: 0.2609
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4061 - loss: 2.8215 - weighted_accuracy: 0.4061 - val_accuracy: 0.3208 - val_loss: 3.0543 - val_weighted_accuracy: 0.3208
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4497 - loss: 2.4231 - weighted_accuracy: 0.4497 - val_accuracy: 0.3838 - val_loss: 2.6857 - val_weighted_accuracy: 0.3838
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5154 - loss: 2.0742 - weighted_accuracy: 0.5154 - val_accuracy: 0.4193 - val_loss: 2.2491 - val_weighted_accuracy: 0.4193
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5738 - loss: 1.7894 - weighted_accuracy: 0.5738 - val_accuracy: 0.4467 - val_loss: 2.1216 - val_weighted_accuracy: 0.4467
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6322 - loss: 1.5435 - weighted_accuracy: 0.6322 - val_accuracy: 0.3919 - val_loss: 2.5707 - val_weighted_accuracy: 0.3919
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6578 - loss: 1.4105 - weighted_accuracy: 0.6578 - val_accuracy: 0.3371 - val_loss: 3.0454 - val_weighted_accuracy: 0.3371
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6851 - loss: 1.3136 - weighted_accuracy: 0.6851 - val_accuracy: 0.5421 - val_loss: 1.8601 - val_weighted_accuracy: 0.5421
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7251 - loss: 1.1699 - weighted_accuracy: 0.7251 - val_accuracy: 0.5350 - val_loss: 1.8727 - val_weighted_accuracy: 0.5350
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7185 - loss: 1.1478 - weighted_accuracy: 0.7185 - val_accuracy: 0.5198 - val_loss: 1.9828 - val_weighted_accuracy: 0.5198
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7374 - loss: 1.0695 - weighted_accuracy: 0.7374 - val_accuracy: 0.5036 - val_loss: 1.8272 - val_weighted_accuracy: 0.5036
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7752 - loss: 0.9566 - weighted_accuracy: 0.7752 - val_accuracy: 0.5807 - val_loss: 1.6096 - val_weighted_accuracy: 0.5807
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7803 - loss: 0.9202 - weighted_accuracy: 0.7803 - val_accuracy: 0.5797 - val_loss: 1.6441 - val_weighted_accuracy: 0.5797
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8197 - loss: 0.8460 - weighted_accuracy: 0.8197 - val_accuracy: 0.4904 - val_loss: 2.2129 - val_weighted_accuracy: 0.4904
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8208 - loss: 0.8080 - weighted_accuracy: 0.8208 - val_accuracy: 0.6305 - val_loss: 1.4899 - val_weighted_accuracy: 0.6305
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8222 - loss: 0.7702 - weighted_accuracy: 0.8222 - val_accuracy: 0.4782 - val_loss: 2.4425 - val_weighted_accuracy: 0.4782
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8346 - loss: 0.7661 - weighted_accuracy: 0.8346 - val_accuracy: 0.6041 - val_loss: 1.7274 - val_weighted_accuracy: 0.6041
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8533 - loss: 0.6966 - weighted_accuracy: 0.8533 - val_accuracy: 0.5168 - val_loss: 2.6528 - val_weighted_accuracy: 0.5168
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8516 - loss: 0.7119 - weighted_accuracy: 0.8516 - val_accuracy: 0.6112 - val_loss: 1.8274 - val_weighted_accuracy: 0.6112
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8762 - loss: 0.6362 - weighted_accuracy: 0.8762 - val_accuracy: 0.5574 - val_loss: 2.0548 - val_weighted_accuracy: 0.5574
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8672 - loss: 0.6772 - weighted_accuracy: 0.8672 - val_accuracy: 0.4843 - val_loss: 2.3435 - val_weighted_accuracy: 0.4843
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8847 - loss: 0.6184 - weighted_accuracy: 0.8847 - val_accuracy: 0.6173 - val_loss: 1.8135 - val_weighted_accuracy: 0.6173
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8800 - loss: 0.5993 - weighted_accuracy: 0.8800 - val_accuracy: 0.6223 - val_loss: 1.8529 - val_weighted_accuracy: 0.6223
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8721 - loss: 0.6065 - weighted_accuracy: 0.8721 - val_accuracy: 0.5482 - val_loss: 2.2001 - val_weighted_accuracy: 0.5482
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8853 - loss: 0.5779 - weighted_accuracy: 0.8853 - val_accuracy: 0.5614 - val_loss: 2.1724 - val_weighted_accuracy: 0.5614
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9063 - loss: 0.5249 - weighted_accuracy: 0.9063 - val_accuracy: 0.6041 - val_loss: 1.9102 - val_weighted_accuracy: 0.6041
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9204 - loss: 0.4814 - weighted_accuracy: 0.9204 - val_accuracy: 0.6223 - val_loss: 1.7632 - val_weighted_accuracy: 0.6223
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9112 - loss: 0.5239 - weighted_accuracy: 0.9112 - val_accuracy: 0.6234 - val_loss: 1.9312 - val_weighted_accuracy: 0.6234
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9165 - loss: 0.4875 - weighted_accuracy: 0.9165 - val_accuracy: 0.5990 - val_loss: 2.0564 - val_weighted_accuracy: 0.5990
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9188 - loss: 0.4826 - weighted_accuracy: 0.9188 - val_accuracy: 0.5574 - val_loss: 2.1527 - val_weighted_accuracy: 0.5574
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9170 - loss: 0.4667 - weighted_accuracy: 0.9170 - val_accuracy: 0.6325 - val_loss: 1.8035 - val_weighted_accuracy: 0.6325
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9124 - loss: 0.5014 - weighted_accuracy: 0.9124 - val_accuracy: 0.5614 - val_loss: 2.0954 - val_weighted_accuracy: 0.5614
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9298 - loss: 0.4446 - weighted_accuracy: 0.9298 - val_accuracy: 0.6091 - val_loss: 2.2283 - val_weighted_accuracy: 0.6091
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9260 - loss: 0.4664 - weighted_accuracy: 0.9260 - val_accuracy: 0.4437 - val_loss: 3.5431 - val_weighted_accuracy: 0.4437
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9337 - loss: 0.4306 - weighted_accuracy: 0.9337 - val_accuracy: 0.5939 - val_loss: 2.3191 - val_weighted_accuracy: 0.5939
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9365 - loss: 0.4104 - weighted_accuracy: 0.9365 - val_accuracy: 0.5604 - val_loss: 2.2349 - val_weighted_accuracy: 0.5604
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9402 - loss: 0.4000 - weighted_accuracy: 0.9402 - val_accuracy: 0.5858 - val_loss: 2.0758 - val_weighted_accuracy: 0.5858
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9263 - loss: 0.4338 - weighted_accuracy: 0.9263 - val_accuracy: 0.5756 - val_loss: 2.2474 - val_weighted_accuracy: 0.5756
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9526 - loss: 0.3658 - weighted_accuracy: 0.9526 - val_accuracy: 0.6629 - val_loss: 1.7615 - val_weighted_accuracy: 0.6629
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9362 - loss: 0.3980 - weighted_accuracy: 0.9362 - val_accuracy: 0.5848 - val_loss: 2.3469 - val_weighted_accuracy: 0.5848
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9470 - loss: 0.3674 - weighted_accuracy: 0.9470 - val_accuracy: 0.6030 - val_loss: 2.2621 - val_weighted_accuracy: 0.6030
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9431 - loss: 0.3766 - weighted_accuracy: 0.9431 - val_accuracy: 0.5949 - val_loss: 2.2716 - val_weighted_accuracy: 0.5949
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9597 - loss: 0.3303 - weighted_accuracy: 0.9597 - val_accuracy: 0.6518 - val_loss: 1.9374 - val_weighted_accuracy: 0.6518
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9532 - loss: 0.3486 - weighted_accuracy: 0.9532 - val_accuracy: 0.6365 - val_loss: 1.9146 - val_weighted_accuracy: 0.6365
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9501 - loss: 0.3410 - weighted_accuracy: 0.9501 - val_accuracy: 0.6102 - val_loss: 2.0609 - val_weighted_accuracy: 0.6102
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9482 - loss: 0.3439 - weighted_accuracy: 0.9482 - val_accuracy: 0.6802 - val_loss: 1.5639 - val_weighted_accuracy: 0.6802
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9457 - loss: 0.3711 - weighted_accuracy: 0.9457 - val_accuracy: 0.5959 - val_loss: 2.1820 - val_weighted_accuracy: 0.5959
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9519 - loss: 0.3425 - weighted_accuracy: 0.9519 - val_accuracy: 0.6528 - val_loss: 1.7598 - val_weighted_accuracy: 0.6528
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9643 - loss: 0.3071 - weighted_accuracy: 0.9643 - val_accuracy: 0.6640 - val_loss: 1.6054 - val_weighted_accuracy: 0.6640
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9640 - loss: 0.3020 - weighted_accuracy: 0.9640 - val_accuracy: 0.6315 - val_loss: 1.8348 - val_weighted_accuracy: 0.6315
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9657 - loss: 0.3015 - weighted_accuracy: 0.9657 - val_accuracy: 0.5695 - val_loss: 2.4521 - val_weighted_accuracy: 0.5695
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9541 - loss: 0.3225 - weighted_accuracy: 0.9541 - val_accuracy: 0.5685 - val_loss: 2.5435 - val_weighted_accuracy: 0.5685
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9553 - loss: 0.3336 - weighted_accuracy: 0.9553 - val_accuracy: 0.6711 - val_loss: 1.7202 - val_weighted_accuracy: 0.6711
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9618 - loss: 0.3182 - weighted_accuracy: 0.9618 - val_accuracy: 0.6396 - val_loss: 1.8951 - val_weighted_accuracy: 0.6396
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9645 - loss: 0.2956 - weighted_accuracy: 0.9645 - val_accuracy: 0.6162 - val_loss: 2.5185 - val_weighted_accuracy: 0.6162
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9640 - loss: 0.3023 - weighted_accuracy: 0.9640 - val_accuracy: 0.5584 - val_loss: 2.6435 - val_weighted_accuracy: 0.5584
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9697 - loss: 0.2895 - weighted_accuracy: 0.9697 - val_accuracy: 0.6670 - val_loss: 1.8128 - val_weighted_accuracy: 0.6670
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9699 - loss: 0.2691 - weighted_accuracy: 0.9699 - val_accuracy: 0.6345 - val_loss: 1.8876 - val_weighted_accuracy: 0.6345
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9692 - loss: 0.2755 - weighted_accuracy: 0.9692 - val_accuracy: 0.6985 - val_loss: 1.6523 - val_weighted_accuracy: 0.6985
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9775 - loss: 0.2401 - weighted_accuracy: 0.9775 - val_accuracy: 0.6152 - val_loss: 2.0718 - val_weighted_accuracy: 0.6152
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9758 - loss: 0.2424 - weighted_accuracy: 0.9758 - val_accuracy: 0.6670 - val_loss: 2.0916 - val_weighted_accuracy: 0.6670
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9737 - loss: 0.2486 - weighted_accuracy: 0.9737 - val_accuracy: 0.6223 - val_loss: 2.0759 - val_weighted_accuracy: 0.6223
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9681 - loss: 0.2795 - weighted_accuracy: 0.9681 - val_accuracy: 0.6041 - val_loss: 2.6773 - val_weighted_accuracy: 0.6041
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9665 - loss: 0.2834 - weighted_accuracy: 0.9665 - val_accuracy: 0.5878 - val_loss: 2.4126 - val_weighted_accuracy: 0.5878
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9655 - loss: 0.2852 - weighted_accuracy: 0.9655 - val_accuracy: 0.6528 - val_loss: 2.0358 - val_weighted_accuracy: 0.6528
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9672 - loss: 0.2630 - weighted_accuracy: 0.9672 - val_accuracy: 0.6518 - val_loss: 1.8965 - val_weighted_accuracy: 0.6518
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9766 - loss: 0.2448 - weighted_accuracy: 0.9766 - val_accuracy: 0.6883 - val_loss: 1.6865 - val_weighted_accuracy: 0.6883
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9769 - loss: 0.2446 - weighted_accuracy: 0.9769 - val_accuracy: 0.6173 - val_loss: 2.2746 - val_weighted_accuracy: 0.6173
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9669 - loss: 0.2730 - weighted_accuracy: 0.9669 - val_accuracy: 0.6061 - val_loss: 2.4838 - val_weighted_accuracy: 0.6061
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9697 - loss: 0.2645 - weighted_accuracy: 0.9697 - val_accuracy: 0.5868 - val_loss: 2.4643 - val_weighted_accuracy: 0.5868
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9686 - loss: 0.2720 - weighted_accuracy: 0.9686 - val_accuracy: 0.6609 - val_loss: 1.9344 - val_weighted_accuracy: 0.6609
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9773 - loss: 0.2344 - weighted_accuracy: 0.9773 - val_accuracy: 0.6609 - val_loss: 1.6211 - val_weighted_accuracy: 0.6609
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9650 - loss: 0.2652 - weighted_accuracy: 0.9650 - val_accuracy: 0.4376 - val_loss: 4.5056 - val_weighted_accuracy: 0.4376
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9667 - loss: 0.2777 - weighted_accuracy: 0.9667 - val_accuracy: 0.6792 - val_loss: 1.8305 - val_weighted_accuracy: 0.6792
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9713 - loss: 0.2399 - weighted_accuracy: 0.9713 - val_accuracy: 0.6670 - val_loss: 1.9297 - val_weighted_accuracy: 0.6670
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9793 - loss: 0.2367 - weighted_accuracy: 0.9793 - val_accuracy: 0.6680 - val_loss: 1.7737 - val_weighted_accuracy: 0.6680
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9811 - loss: 0.2228 - weighted_accuracy: 0.9811 - val_accuracy: 0.5838 - val_loss: 2.3617 - val_weighted_accuracy: 0.5838
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9744 - loss: 0.2311 - weighted_accuracy: 0.9744 - val_accuracy: 0.6426 - val_loss: 1.8249 - val_weighted_accuracy: 0.6426
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9774 - loss: 0.2183 - weighted_accuracy: 0.9774 - val_accuracy: 0.6558 - val_loss: 1.9895 - val_weighted_accuracy: 0.6558
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9852 - loss: 0.1934 - weighted_accuracy: 0.9852 - val_accuracy: 0.6365 - val_loss: 2.2516 - val_weighted_accuracy: 0.6365
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9871 - loss: 0.1840 - weighted_accuracy: 0.9871 - val_accuracy: 0.6426 - val_loss: 2.1434 - val_weighted_accuracy: 0.6426
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9774 - loss: 0.2142 - weighted_accuracy: 0.9774 - val_accuracy: 0.5848 - val_loss: 2.7094 - val_weighted_accuracy: 0.5848
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9771 - loss: 0.2162 - weighted_accuracy: 0.9771 - val_accuracy: 0.6081 - val_loss: 2.6895 - val_weighted_accuracy: 0.6081
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9759 - loss: 0.2352 - weighted_accuracy: 0.9759 - val_accuracy: 0.6853 - val_loss: 1.9368 - val_weighted_accuracy: 0.6853
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9697 - loss: 0.2583 - weighted_accuracy: 0.9697 - val_accuracy: 0.6152 - val_loss: 2.2736 - val_weighted_accuracy: 0.6152
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9827 - loss: 0.2119 - weighted_accuracy: 0.9827 - val_accuracy: 0.5990 - val_loss: 2.5051 - val_weighted_accuracy: 0.5990
# Epoch 88/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9694 - loss: 0.2510 - weighted_accuracy: 0.9694 - val_accuracy: 0.6406 - val_loss: 2.0096 - val_weighted_accuracy: 0.6406
# Epoch 89/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9863 - loss: 0.1999 - weighted_accuracy: 0.9863 - val_accuracy: 0.6619 - val_loss: 2.1725 - val_weighted_accuracy: 0.6619
# Epoch 90/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9869 - loss: 0.1875 - weighted_accuracy: 0.9869 - val_accuracy: 0.6030 - val_loss: 2.0726 - val_weighted_accuracy: 0.6030
# Epoch 91/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9720 - loss: 0.2348 - weighted_accuracy: 0.9720 - val_accuracy: 0.6447 - val_loss: 2.1112 - val_weighted_accuracy: 0.6447
# Epoch 92/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9791 - loss: 0.2209 - weighted_accuracy: 0.9791 - val_accuracy: 0.6112 - val_loss: 2.4729 - val_weighted_accuracy: 0.6112
# Epoch 93/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9789 - loss: 0.2275 - weighted_accuracy: 0.9789 - val_accuracy: 0.7025 - val_loss: 1.7277 - val_weighted_accuracy: 0.7025
# Epoch 94/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9870 - loss: 0.1819 - weighted_accuracy: 0.9870 - val_accuracy: 0.6934 - val_loss: 1.7255 - val_weighted_accuracy: 0.6934
# Epoch 95/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9820 - loss: 0.1936 - weighted_accuracy: 0.9820 - val_accuracy: 0.6548 - val_loss: 2.0294 - val_weighted_accuracy: 0.6548
# Epoch 96/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9866 - loss: 0.1711 - weighted_accuracy: 0.9866 - val_accuracy: 0.6650 - val_loss: 2.1004 - val_weighted_accuracy: 0.6650
# Epoch 97/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9919 - loss: 0.1706 - weighted_accuracy: 0.9919 - val_accuracy: 0.6843 - val_loss: 1.8919 - val_weighted_accuracy: 0.6843
# Epoch 98/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9893 - loss: 0.1706 - weighted_accuracy: 0.9893 - val_accuracy: 0.6904 - val_loss: 1.6308 - val_weighted_accuracy: 0.6904
# Epoch 99/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9903 - loss: 0.1671 - weighted_accuracy: 0.9903 - val_accuracy: 0.6640 - val_loss: 2.0989 - val_weighted_accuracy: 0.6640
# Epoch 100/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9723 - loss: 0.2186 - weighted_accuracy: 0.9723 - val_accuracy: 0.6264 - val_loss: 2.3319 - val_weighted_accuracy: 0.6264

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['all_features'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['all_features'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.1531 - weighted_accuracy: 0.9922
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6790 - loss: 1.7204 - weighted_accuracy: 0.6790

# %% [markdown]
# ## **With Mel-Spectrogram, MFCCs, Chroma**

# %%
training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma']), axis=1)

print(training_features.shape)
# Out:
# (3954, 92, 259)

# %%
validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma']), axis=1)

print(validation_features.shape)
# Out:
# (985, 92, 259)

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=90
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             660 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 452,276 (1.73 MB)
#  Trainable params: 451,764 (1.72 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.1820 - loss: 4.4093 - weighted_accuracy: 0.1820 - val_accuracy: 0.1391 - val_loss: 4.0245 - val_weighted_accuracy: 0.1391
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3270 - loss: 3.3953 - weighted_accuracy: 0.3270 - val_accuracy: 0.3584 - val_loss: 3.2459 - val_weighted_accuracy: 0.3584
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3846 - loss: 2.8006 - weighted_accuracy: 0.3846 - val_accuracy: 0.2467 - val_loss: 3.5628 - val_weighted_accuracy: 0.2467
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4308 - loss: 2.3751 - weighted_accuracy: 0.4308 - val_accuracy: 0.3614 - val_loss: 2.4075 - val_weighted_accuracy: 0.3614
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4700 - loss: 2.0674 - weighted_accuracy: 0.4700 - val_accuracy: 0.4690 - val_loss: 2.3982 - val_weighted_accuracy: 0.4690
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5099 - loss: 1.8710 - weighted_accuracy: 0.5099 - val_accuracy: 0.4396 - val_loss: 2.2722 - val_weighted_accuracy: 0.4396
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5657 - loss: 1.6756 - weighted_accuracy: 0.5657 - val_accuracy: 0.3807 - val_loss: 2.2125 - val_weighted_accuracy: 0.3807
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6111 - loss: 1.5540 - weighted_accuracy: 0.6111 - val_accuracy: 0.3015 - val_loss: 3.6097 - val_weighted_accuracy: 0.3015
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6283 - loss: 1.4320 - weighted_accuracy: 0.6283 - val_accuracy: 0.3624 - val_loss: 2.3323 - val_weighted_accuracy: 0.3624
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6458 - loss: 1.3087 - weighted_accuracy: 0.6458 - val_accuracy: 0.4477 - val_loss: 2.4001 - val_weighted_accuracy: 0.4477
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7050 - loss: 1.1716 - weighted_accuracy: 0.7050 - val_accuracy: 0.3898 - val_loss: 2.8335 - val_weighted_accuracy: 0.3898
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7260 - loss: 1.0903 - weighted_accuracy: 0.7260 - val_accuracy: 0.5086 - val_loss: 1.7797 - val_weighted_accuracy: 0.5086
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7186 - loss: 1.0863 - weighted_accuracy: 0.7186 - val_accuracy: 0.4132 - val_loss: 2.3984 - val_weighted_accuracy: 0.4132
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7491 - loss: 1.0011 - weighted_accuracy: 0.7491 - val_accuracy: 0.4528 - val_loss: 2.4028 - val_weighted_accuracy: 0.4528
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7746 - loss: 0.9231 - weighted_accuracy: 0.7746 - val_accuracy: 0.3695 - val_loss: 2.7183 - val_weighted_accuracy: 0.3695
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7773 - loss: 0.9200 - weighted_accuracy: 0.7773 - val_accuracy: 0.5533 - val_loss: 1.9618 - val_weighted_accuracy: 0.5533
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7842 - loss: 0.9085 - weighted_accuracy: 0.7842 - val_accuracy: 0.5706 - val_loss: 1.8915 - val_weighted_accuracy: 0.5706
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8242 - loss: 0.7866 - weighted_accuracy: 0.8242 - val_accuracy: 0.5208 - val_loss: 2.0020 - val_weighted_accuracy: 0.5208
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8305 - loss: 0.7670 - weighted_accuracy: 0.8305 - val_accuracy: 0.5645 - val_loss: 2.0350 - val_weighted_accuracy: 0.5645
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8557 - loss: 0.7207 - weighted_accuracy: 0.8557 - val_accuracy: 0.4863 - val_loss: 2.5267 - val_weighted_accuracy: 0.4863
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8543 - loss: 0.6967 - weighted_accuracy: 0.8543 - val_accuracy: 0.5574 - val_loss: 2.1636 - val_weighted_accuracy: 0.5574
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8524 - loss: 0.6978 - weighted_accuracy: 0.8524 - val_accuracy: 0.5838 - val_loss: 2.0300 - val_weighted_accuracy: 0.5838
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8526 - loss: 0.6757 - weighted_accuracy: 0.8526 - val_accuracy: 0.6335 - val_loss: 1.5940 - val_weighted_accuracy: 0.6335
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8882 - loss: 0.5882 - weighted_accuracy: 0.8882 - val_accuracy: 0.5168 - val_loss: 2.2399 - val_weighted_accuracy: 0.5168
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8817 - loss: 0.6171 - weighted_accuracy: 0.8817 - val_accuracy: 0.6284 - val_loss: 1.7780 - val_weighted_accuracy: 0.6284
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8861 - loss: 0.5881 - weighted_accuracy: 0.8861 - val_accuracy: 0.4569 - val_loss: 2.6695 - val_weighted_accuracy: 0.4569
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8937 - loss: 0.5673 - weighted_accuracy: 0.8937 - val_accuracy: 0.6447 - val_loss: 1.6654 - val_weighted_accuracy: 0.6447
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8920 - loss: 0.5801 - weighted_accuracy: 0.8920 - val_accuracy: 0.6071 - val_loss: 2.1004 - val_weighted_accuracy: 0.6071
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8916 - loss: 0.5641 - weighted_accuracy: 0.8916 - val_accuracy: 0.5929 - val_loss: 2.0471 - val_weighted_accuracy: 0.5929
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9076 - loss: 0.5325 - weighted_accuracy: 0.9076 - val_accuracy: 0.5442 - val_loss: 2.5240 - val_weighted_accuracy: 0.5442
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9100 - loss: 0.4893 - weighted_accuracy: 0.9100 - val_accuracy: 0.6071 - val_loss: 2.0664 - val_weighted_accuracy: 0.6071
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9264 - loss: 0.4493 - weighted_accuracy: 0.9264 - val_accuracy: 0.6355 - val_loss: 1.8341 - val_weighted_accuracy: 0.6355
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9133 - loss: 0.4995 - weighted_accuracy: 0.9133 - val_accuracy: 0.5056 - val_loss: 2.7669 - val_weighted_accuracy: 0.5056
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9278 - loss: 0.4722 - weighted_accuracy: 0.9278 - val_accuracy: 0.6183 - val_loss: 1.8729 - val_weighted_accuracy: 0.6183
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9327 - loss: 0.4212 - weighted_accuracy: 0.9327 - val_accuracy: 0.5563 - val_loss: 2.6348 - val_weighted_accuracy: 0.5563
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9340 - loss: 0.4534 - weighted_accuracy: 0.9340 - val_accuracy: 0.6447 - val_loss: 1.7695 - val_weighted_accuracy: 0.6447
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9441 - loss: 0.4058 - weighted_accuracy: 0.9441 - val_accuracy: 0.5442 - val_loss: 2.5226 - val_weighted_accuracy: 0.5442
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9405 - loss: 0.3986 - weighted_accuracy: 0.9405 - val_accuracy: 0.5898 - val_loss: 2.6641 - val_weighted_accuracy: 0.5898
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9397 - loss: 0.4250 - weighted_accuracy: 0.9397 - val_accuracy: 0.6183 - val_loss: 2.1297 - val_weighted_accuracy: 0.6183
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9472 - loss: 0.3786 - weighted_accuracy: 0.9472 - val_accuracy: 0.6305 - val_loss: 1.8186 - val_weighted_accuracy: 0.6305
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9450 - loss: 0.4077 - weighted_accuracy: 0.9450 - val_accuracy: 0.6386 - val_loss: 1.8709 - val_weighted_accuracy: 0.6386
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9449 - loss: 0.3887 - weighted_accuracy: 0.9449 - val_accuracy: 0.6183 - val_loss: 2.1105 - val_weighted_accuracy: 0.6183
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9549 - loss: 0.3466 - weighted_accuracy: 0.9549 - val_accuracy: 0.5695 - val_loss: 2.5927 - val_weighted_accuracy: 0.5695
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9493 - loss: 0.3673 - weighted_accuracy: 0.9493 - val_accuracy: 0.6721 - val_loss: 1.7774 - val_weighted_accuracy: 0.6721
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9570 - loss: 0.3273 - weighted_accuracy: 0.9570 - val_accuracy: 0.5096 - val_loss: 3.3449 - val_weighted_accuracy: 0.5096
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9624 - loss: 0.3192 - weighted_accuracy: 0.9624 - val_accuracy: 0.6386 - val_loss: 2.1016 - val_weighted_accuracy: 0.6386
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9634 - loss: 0.3152 - weighted_accuracy: 0.9634 - val_accuracy: 0.6020 - val_loss: 2.4587 - val_weighted_accuracy: 0.6020
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9524 - loss: 0.3459 - weighted_accuracy: 0.9524 - val_accuracy: 0.6010 - val_loss: 2.3145 - val_weighted_accuracy: 0.6010
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9557 - loss: 0.3368 - weighted_accuracy: 0.9557 - val_accuracy: 0.6396 - val_loss: 1.8392 - val_weighted_accuracy: 0.6396
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9623 - loss: 0.3312 - weighted_accuracy: 0.9623 - val_accuracy: 0.5817 - val_loss: 2.4086 - val_weighted_accuracy: 0.5817
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9663 - loss: 0.3008 - weighted_accuracy: 0.9663 - val_accuracy: 0.6000 - val_loss: 2.1789 - val_weighted_accuracy: 0.6000
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9634 - loss: 0.3144 - weighted_accuracy: 0.9634 - val_accuracy: 0.6193 - val_loss: 2.0898 - val_weighted_accuracy: 0.6193
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9631 - loss: 0.3051 - weighted_accuracy: 0.9631 - val_accuracy: 0.6558 - val_loss: 1.8874 - val_weighted_accuracy: 0.6558
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9476 - loss: 0.3598 - weighted_accuracy: 0.9476 - val_accuracy: 0.6020 - val_loss: 2.0356 - val_weighted_accuracy: 0.6020
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9602 - loss: 0.3121 - weighted_accuracy: 0.9602 - val_accuracy: 0.5279 - val_loss: 3.0402 - val_weighted_accuracy: 0.5279
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9668 - loss: 0.2924 - weighted_accuracy: 0.9668 - val_accuracy: 0.6213 - val_loss: 2.0753 - val_weighted_accuracy: 0.6213
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9797 - loss: 0.2608 - weighted_accuracy: 0.9797 - val_accuracy: 0.6690 - val_loss: 2.0244 - val_weighted_accuracy: 0.6690
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9744 - loss: 0.2631 - weighted_accuracy: 0.9744 - val_accuracy: 0.6234 - val_loss: 1.9382 - val_weighted_accuracy: 0.6234
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9836 - loss: 0.2362 - weighted_accuracy: 0.9836 - val_accuracy: 0.6132 - val_loss: 2.2816 - val_weighted_accuracy: 0.6132
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9626 - loss: 0.2785 - weighted_accuracy: 0.9626 - val_accuracy: 0.6264 - val_loss: 2.1305 - val_weighted_accuracy: 0.6264
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9495 - loss: 0.3448 - weighted_accuracy: 0.9495 - val_accuracy: 0.6558 - val_loss: 2.1549 - val_weighted_accuracy: 0.6558
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9677 - loss: 0.2953 - weighted_accuracy: 0.9677 - val_accuracy: 0.6020 - val_loss: 2.4273 - val_weighted_accuracy: 0.6020
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9731 - loss: 0.2717 - weighted_accuracy: 0.9731 - val_accuracy: 0.6711 - val_loss: 1.9400 - val_weighted_accuracy: 0.6711
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9739 - loss: 0.2554 - weighted_accuracy: 0.9739 - val_accuracy: 0.6528 - val_loss: 2.2843 - val_weighted_accuracy: 0.6528
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9679 - loss: 0.2612 - weighted_accuracy: 0.9679 - val_accuracy: 0.6497 - val_loss: 1.9040 - val_weighted_accuracy: 0.6497
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9607 - loss: 0.2868 - weighted_accuracy: 0.9607 - val_accuracy: 0.6386 - val_loss: 2.2156 - val_weighted_accuracy: 0.6386
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9765 - loss: 0.2383 - weighted_accuracy: 0.9765 - val_accuracy: 0.6345 - val_loss: 2.0304 - val_weighted_accuracy: 0.6345
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9580 - loss: 0.2983 - weighted_accuracy: 0.9580 - val_accuracy: 0.6924 - val_loss: 1.8883 - val_weighted_accuracy: 0.6924
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9814 - loss: 0.2252 - weighted_accuracy: 0.9814 - val_accuracy: 0.6284 - val_loss: 2.2526 - val_weighted_accuracy: 0.6284
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9719 - loss: 0.2625 - weighted_accuracy: 0.9719 - val_accuracy: 0.6477 - val_loss: 2.2772 - val_weighted_accuracy: 0.6477
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9628 - loss: 0.2790 - weighted_accuracy: 0.9628 - val_accuracy: 0.6721 - val_loss: 1.9371 - val_weighted_accuracy: 0.6721
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9833 - loss: 0.2164 - weighted_accuracy: 0.9833 - val_accuracy: 0.6548 - val_loss: 1.8875 - val_weighted_accuracy: 0.6548
# Epoch 73/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9797 - loss: 0.2244 - weighted_accuracy: 0.9797 - val_accuracy: 0.6386 - val_loss: 2.4115 - val_weighted_accuracy: 0.6386
# Epoch 74/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9841 - loss: 0.2065 - weighted_accuracy: 0.9841 - val_accuracy: 0.6711 - val_loss: 2.0891 - val_weighted_accuracy: 0.6711
# Epoch 75/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9676 - loss: 0.2494 - weighted_accuracy: 0.9676 - val_accuracy: 0.6721 - val_loss: 1.7053 - val_weighted_accuracy: 0.6721
# Epoch 76/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9783 - loss: 0.2291 - weighted_accuracy: 0.9783 - val_accuracy: 0.6173 - val_loss: 2.3508 - val_weighted_accuracy: 0.6173
# Epoch 77/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9705 - loss: 0.2548 - weighted_accuracy: 0.9705 - val_accuracy: 0.6102 - val_loss: 2.4164 - val_weighted_accuracy: 0.6102
# Epoch 78/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9667 - loss: 0.2838 - weighted_accuracy: 0.9667 - val_accuracy: 0.6558 - val_loss: 1.9011 - val_weighted_accuracy: 0.6558
# Epoch 79/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9705 - loss: 0.2712 - weighted_accuracy: 0.9705 - val_accuracy: 0.6365 - val_loss: 2.1775 - val_weighted_accuracy: 0.6365
# Epoch 80/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9770 - loss: 0.2505 - weighted_accuracy: 0.9770 - val_accuracy: 0.6650 - val_loss: 1.9442 - val_weighted_accuracy: 0.6650
# Epoch 81/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9696 - loss: 0.2785 - weighted_accuracy: 0.9696 - val_accuracy: 0.6680 - val_loss: 2.2092 - val_weighted_accuracy: 0.6680
# Epoch 82/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9858 - loss: 0.2051 - weighted_accuracy: 0.9858 - val_accuracy: 0.6508 - val_loss: 1.8911 - val_weighted_accuracy: 0.6508
# Epoch 83/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9744 - loss: 0.2347 - weighted_accuracy: 0.9744 - val_accuracy: 0.6690 - val_loss: 2.0860 - val_weighted_accuracy: 0.6690
# Epoch 84/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9778 - loss: 0.2235 - weighted_accuracy: 0.9778 - val_accuracy: 0.6335 - val_loss: 2.1372 - val_weighted_accuracy: 0.6335
# Epoch 85/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9874 - loss: 0.2016 - weighted_accuracy: 0.9874 - val_accuracy: 0.6629 - val_loss: 2.3080 - val_weighted_accuracy: 0.6629
# Epoch 86/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9819 - loss: 0.2068 - weighted_accuracy: 0.9819 - val_accuracy: 0.6883 - val_loss: 1.9610 - val_weighted_accuracy: 0.6883
# Epoch 87/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9848 - loss: 0.2087 - weighted_accuracy: 0.9848 - val_accuracy: 0.6132 - val_loss: 2.4303 - val_weighted_accuracy: 0.6132
# Epoch 88/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9759 - loss: 0.2356 - weighted_accuracy: 0.9759 - val_accuracy: 0.6629 - val_loss: 2.1351 - val_weighted_accuracy: 0.6629
# Epoch 89/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9585 - loss: 0.3034 - weighted_accuracy: 0.9585 - val_accuracy: 0.6203 - val_loss: 2.3555 - val_weighted_accuracy: 0.6203
# Epoch 90/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9780 - loss: 0.2385 - weighted_accuracy: 0.9780 - val_accuracy: 0.6193 - val_loss: 2.2980 - val_weighted_accuracy: 0.6193
# Epoch 91/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9698 - loss: 0.2637 - weighted_accuracy: 0.9698 - val_accuracy: 0.6589 - val_loss: 2.2817 - val_weighted_accuracy: 0.6589
# Epoch 92/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9694 - loss: 0.2373 - weighted_accuracy: 0.9694 - val_accuracy: 0.6751 - val_loss: 1.6547 - val_weighted_accuracy: 0.6751
# Epoch 93/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9834 - loss: 0.2100 - weighted_accuracy: 0.9834 - val_accuracy: 0.6944 - val_loss: 1.8437 - val_weighted_accuracy: 0.6944
# Epoch 94/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9842 - loss: 0.1924 - weighted_accuracy: 0.9842 - val_accuracy: 0.6792 - val_loss: 1.8584 - val_weighted_accuracy: 0.6792
# Epoch 95/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9835 - loss: 0.1944 - weighted_accuracy: 0.9835 - val_accuracy: 0.5391 - val_loss: 2.8903 - val_weighted_accuracy: 0.5391
# Epoch 96/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9798 - loss: 0.2191 - weighted_accuracy: 0.9798 - val_accuracy: 0.6609 - val_loss: 2.2967 - val_weighted_accuracy: 0.6609
# Epoch 97/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9648 - loss: 0.2606 - weighted_accuracy: 0.9648 - val_accuracy: 0.6081 - val_loss: 2.2973 - val_weighted_accuracy: 0.6081
# Epoch 98/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9622 - loss: 0.2607 - weighted_accuracy: 0.9622 - val_accuracy: 0.6386 - val_loss: 2.2566 - val_weighted_accuracy: 0.6386
# Epoch 99/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9833 - loss: 0.2144 - weighted_accuracy: 0.9833 - val_accuracy: 0.6447 - val_loss: 2.1427 - val_weighted_accuracy: 0.6447
# Epoch 100/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9742 - loss: 0.2361 - weighted_accuracy: 0.9742 - val_accuracy: 0.6680 - val_loss: 2.0772 - val_weighted_accuracy: 0.6680

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['melspectrogram_chroma_mfcc'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['melspectrogram_chroma_mfcc'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9951 - loss: 0.1689 - weighted_accuracy: 0.9951
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6502 - loss: 1.7832 - weighted_accuracy: 0.6502

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(3)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(3)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Features')
result_df
# Out:
#                      Features  Train_Accuracy  Val_Accuracy
# 0                all_features           0.992         0.690
# 1  melspectrogram_chroma_mfcc           0.995         0.675
