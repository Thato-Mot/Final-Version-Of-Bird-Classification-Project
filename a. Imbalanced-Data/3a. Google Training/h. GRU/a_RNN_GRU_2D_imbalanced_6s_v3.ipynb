# %% [markdown]
# # **CNN**
# - Using data that was not annotated
# - Training it on the unbalanced data
# - Using avgpool
# - 6 second window

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard libraries
import numpy as np
import pandas as pd
import time
import os

# For audio
from IPython.display import Audio
import librosa

# For preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# For modeling
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Operational
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.ndimage
import pygame
import time
from scipy.signal import butter, filtfilt
import random
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pkl_path = '/content/drive/My Drive/Final-Year-Project/Dataset/Project-V4/feature-extraction/Annotated/NotAveragePooled/split_features_6s_all.pkl'

# Load the pickle file
with open(pkl_path, 'rb') as file:
    data = pickle.load(file)

# %%
train_data = data['train'].copy()
val_data = data['val'].copy()

# %%
# train_data]

# %%
train_labels = train_data['label'].copy()
temp = train_data.copy()
del temp['label']
tr_features = temp

# %%
val_labels = val_data['label'].copy()
temp = val_data.copy()
del temp['label']
v_features = temp

# %% [markdown]
# # Shuffle Data

# %%
def shuffle_data(input_label, input_features):
  input_len = len(input_label)
  np.random.seed(1826)
  input_indices = np.random.permutation(input_len)
  input_features = {key: np.array([input_features[key][i] for i in input_indices]) for key in input_features} # dictionary comprehension
  input_label = np.array([input_label[i] for i in input_indices])

  return input_label, input_features

# %%
train_y, train_features = shuffle_data(train_labels, tr_features)

# %%
val_y, val_features = shuffle_data(val_labels, v_features)

# %% [markdown]
# ## **LSTM Model**

# %%
def build_model(audio_features,
                learning_rate=0.001,
                gru=256,
                hidden=[128,128,32],
                dropout=0.5):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # add sequential model
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.GRU(gru, input_shape=(audio_features.shape[1],audio_features.shape[2])))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(dropout))

  for size in hidden:
    model.add(tf.keras.layers.Dense(size, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.015)))
    model.add(tf.keras.layers.Dropout(dropout))

  model.add(tf.keras.layers.Dense(units=20,activation='softmax'))

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Visualize the loss
    axes[0].plot(model_history.history['loss'], color='red', label='Training Loss')
    axes[0].plot(model_history.history['val_loss'], color='blue', label='Validation Loss')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].set_title('Loss Progression', fontsize=14)
    axes[0].grid(True)
    axes[0].legend()

    # Visualize the accuracy
    axes[1].plot(model_history.history['accuracy'], color='green', label='Training Accuracy')
    axes[1].plot(model_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].set_title('Accuracy Progression', fontsize=14)
    axes[1].grid(True)
    axes[1].legend()

    # Fine-tune layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
train_results = {}
val_results = {}

# %% [markdown]
# ### **With all the features**

# %%
# n_time = train_features['melspectrogram'].shape[2]

# mfcc_tiled = np.tile(train_features['mfcc'], (1, 3, 1))  # (3318, 60, 44), tiling 3 times to match 60 features
# chroma_tiled = np.tile(train_features['chroma'], (1, 5, 1))  # (3318, 60, 44), tiling 5 times to match 60 features
# rms_tiled = np.tile(train_features['rms'], (1, 60, 1))  # (3318, 60, 44), tiling 60 times to match 60 features

training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma'], train_features['rms']), axis=1)

print(training_features.shape)
# Out:
# (3954, 93, 259)

# %%
# mfcc_val_tiled = np.tile(val_features['mfcc'], (1, 3, 1))  # Tile to (n_samples_val, 60, 44)
# chroma_val_tiled = np.tile(val_features['chroma'], (1, 5, 1))  # Tile to (n_samples_val, 60, 44)
# rms_val_tiled = np.tile(val_features['rms'], (1, 60, 1))  # Tile to (n_samples_val, 60, 44)

# melspectrogram_val = val_features['melspectrogram']

validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma'], val_features['rms']), axis=1)

print(validation_features.shape)
# Out:
# (985, 93, 259)

# %% [markdown]
# Fit the model with training data

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             660 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 452,276 (1.73 MB)
#  Trainable params: 451,764 (1.72 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0619 - loss: 8.4850 - weighted_accuracy: 0.0619 - val_accuracy: 0.0680 - val_loss: 6.6294 - val_weighted_accuracy: 0.0680
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1157 - loss: 6.1868 - weighted_accuracy: 0.1157 - val_accuracy: 0.2254 - val_loss: 5.1340 - val_weighted_accuracy: 0.2254
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1697 - loss: 4.7090 - weighted_accuracy: 0.1697 - val_accuracy: 0.2680 - val_loss: 3.9968 - val_weighted_accuracy: 0.2680
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2467 - loss: 3.7003 - weighted_accuracy: 0.2467 - val_accuracy: 0.2822 - val_loss: 3.2453 - val_weighted_accuracy: 0.2822
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2785 - loss: 3.0342 - weighted_accuracy: 0.2785 - val_accuracy: 0.3117 - val_loss: 2.6855 - val_weighted_accuracy: 0.3117
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3111 - loss: 2.6817 - weighted_accuracy: 0.3111 - val_accuracy: 0.4112 - val_loss: 2.2724 - val_weighted_accuracy: 0.4112
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3619 - loss: 2.3761 - weighted_accuracy: 0.3619 - val_accuracy: 0.1777 - val_loss: 3.2239 - val_weighted_accuracy: 0.1777
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3694 - loss: 2.2575 - weighted_accuracy: 0.3694 - val_accuracy: 0.2589 - val_loss: 2.6006 - val_weighted_accuracy: 0.2589
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4030 - loss: 2.0951 - weighted_accuracy: 0.4030 - val_accuracy: 0.4020 - val_loss: 2.1812 - val_weighted_accuracy: 0.4020
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3986 - loss: 2.0219 - weighted_accuracy: 0.3986 - val_accuracy: 0.4447 - val_loss: 1.9745 - val_weighted_accuracy: 0.4447
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4215 - loss: 1.9325 - weighted_accuracy: 0.4215 - val_accuracy: 0.3563 - val_loss: 2.1350 - val_weighted_accuracy: 0.3563
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4351 - loss: 1.8409 - weighted_accuracy: 0.4351 - val_accuracy: 0.4061 - val_loss: 2.0471 - val_weighted_accuracy: 0.4061
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4622 - loss: 1.8359 - weighted_accuracy: 0.4622 - val_accuracy: 0.1401 - val_loss: 5.7561 - val_weighted_accuracy: 0.1401
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4484 - loss: 1.8094 - weighted_accuracy: 0.4484 - val_accuracy: 0.3259 - val_loss: 2.1699 - val_weighted_accuracy: 0.3259
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4477 - loss: 1.7618 - weighted_accuracy: 0.4477 - val_accuracy: 0.4030 - val_loss: 1.9731 - val_weighted_accuracy: 0.4030
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4589 - loss: 1.7270 - weighted_accuracy: 0.4589 - val_accuracy: 0.4376 - val_loss: 1.9392 - val_weighted_accuracy: 0.4376
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4763 - loss: 1.7429 - weighted_accuracy: 0.4763 - val_accuracy: 0.4528 - val_loss: 1.7064 - val_weighted_accuracy: 0.4528
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4962 - loss: 1.6899 - weighted_accuracy: 0.4962 - val_accuracy: 0.4051 - val_loss: 1.9501 - val_weighted_accuracy: 0.4051
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4905 - loss: 1.7025 - weighted_accuracy: 0.4905 - val_accuracy: 0.4558 - val_loss: 1.6969 - val_weighted_accuracy: 0.4558
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4905 - loss: 1.6367 - weighted_accuracy: 0.4905 - val_accuracy: 0.4000 - val_loss: 2.0090 - val_weighted_accuracy: 0.4000
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5056 - loss: 1.6449 - weighted_accuracy: 0.5056 - val_accuracy: 0.4701 - val_loss: 1.9695 - val_weighted_accuracy: 0.4701
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5155 - loss: 1.6385 - weighted_accuracy: 0.5155 - val_accuracy: 0.4365 - val_loss: 1.9015 - val_weighted_accuracy: 0.4365
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5101 - loss: 1.6612 - weighted_accuracy: 0.5101 - val_accuracy: 0.5299 - val_loss: 1.7277 - val_weighted_accuracy: 0.5299
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5384 - loss: 1.6004 - weighted_accuracy: 0.5384 - val_accuracy: 0.5117 - val_loss: 1.6803 - val_weighted_accuracy: 0.5117
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5395 - loss: 1.5672 - weighted_accuracy: 0.5395 - val_accuracy: 0.4000 - val_loss: 1.9399 - val_weighted_accuracy: 0.4000
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5554 - loss: 1.5434 - weighted_accuracy: 0.5554 - val_accuracy: 0.5066 - val_loss: 1.8561 - val_weighted_accuracy: 0.5066
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5722 - loss: 1.5082 - weighted_accuracy: 0.5722 - val_accuracy: 0.5391 - val_loss: 1.7969 - val_weighted_accuracy: 0.5391
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5822 - loss: 1.4765 - weighted_accuracy: 0.5822 - val_accuracy: 0.5452 - val_loss: 1.6182 - val_weighted_accuracy: 0.5452
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5828 - loss: 1.5180 - weighted_accuracy: 0.5828 - val_accuracy: 0.5279 - val_loss: 1.6462 - val_weighted_accuracy: 0.5279
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5857 - loss: 1.4668 - weighted_accuracy: 0.5857 - val_accuracy: 0.5888 - val_loss: 1.4972 - val_weighted_accuracy: 0.5888
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5799 - loss: 1.4361 - weighted_accuracy: 0.5799 - val_accuracy: 0.5371 - val_loss: 1.8137 - val_weighted_accuracy: 0.5371
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5886 - loss: 1.4208 - weighted_accuracy: 0.5886 - val_accuracy: 0.5117 - val_loss: 1.8371 - val_weighted_accuracy: 0.5117
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5968 - loss: 1.3947 - weighted_accuracy: 0.5968 - val_accuracy: 0.5563 - val_loss: 1.6950 - val_weighted_accuracy: 0.5563
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6037 - loss: 1.3733 - weighted_accuracy: 0.6037 - val_accuracy: 0.5168 - val_loss: 1.8371 - val_weighted_accuracy: 0.5168
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6060 - loss: 1.3926 - weighted_accuracy: 0.6060 - val_accuracy: 0.5411 - val_loss: 1.8029 - val_weighted_accuracy: 0.5411
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6053 - loss: 1.3994 - weighted_accuracy: 0.6053 - val_accuracy: 0.5523 - val_loss: 1.7176 - val_weighted_accuracy: 0.5523
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6280 - loss: 1.3283 - weighted_accuracy: 0.6280 - val_accuracy: 0.5472 - val_loss: 1.7548 - val_weighted_accuracy: 0.5472
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6461 - loss: 1.2590 - weighted_accuracy: 0.6461 - val_accuracy: 0.5371 - val_loss: 1.6602 - val_weighted_accuracy: 0.5371
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6354 - loss: 1.2895 - weighted_accuracy: 0.6354 - val_accuracy: 0.6081 - val_loss: 1.4829 - val_weighted_accuracy: 0.6081
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6253 - loss: 1.3197 - weighted_accuracy: 0.6253 - val_accuracy: 0.5574 - val_loss: 1.7249 - val_weighted_accuracy: 0.5574
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6286 - loss: 1.3140 - weighted_accuracy: 0.6286 - val_accuracy: 0.5868 - val_loss: 1.5900 - val_weighted_accuracy: 0.5868
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6257 - loss: 1.2918 - weighted_accuracy: 0.6257 - val_accuracy: 0.5401 - val_loss: 1.7098 - val_weighted_accuracy: 0.5401
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6262 - loss: 1.2825 - weighted_accuracy: 0.6262 - val_accuracy: 0.5015 - val_loss: 2.1334 - val_weighted_accuracy: 0.5015
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6417 - loss: 1.2587 - weighted_accuracy: 0.6417 - val_accuracy: 0.5584 - val_loss: 1.9180 - val_weighted_accuracy: 0.5584
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6602 - loss: 1.2355 - weighted_accuracy: 0.6602 - val_accuracy: 0.5959 - val_loss: 1.5650 - val_weighted_accuracy: 0.5959
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6526 - loss: 1.2356 - weighted_accuracy: 0.6526 - val_accuracy: 0.5391 - val_loss: 1.8187 - val_weighted_accuracy: 0.5391
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6504 - loss: 1.2274 - weighted_accuracy: 0.6504 - val_accuracy: 0.5766 - val_loss: 1.7074 - val_weighted_accuracy: 0.5766
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6676 - loss: 1.1782 - weighted_accuracy: 0.6676 - val_accuracy: 0.5503 - val_loss: 1.7855 - val_weighted_accuracy: 0.5503
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6680 - loss: 1.2000 - weighted_accuracy: 0.6680 - val_accuracy: 0.5919 - val_loss: 1.7536 - val_weighted_accuracy: 0.5919
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6654 - loss: 1.2267 - weighted_accuracy: 0.6654 - val_accuracy: 0.6081 - val_loss: 1.5150 - val_weighted_accuracy: 0.6081
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6722 - loss: 1.1756 - weighted_accuracy: 0.6722 - val_accuracy: 0.5939 - val_loss: 1.7003 - val_weighted_accuracy: 0.5939
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6830 - loss: 1.1821 - weighted_accuracy: 0.6830 - val_accuracy: 0.6173 - val_loss: 1.5729 - val_weighted_accuracy: 0.6173
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6887 - loss: 1.1524 - weighted_accuracy: 0.6887 - val_accuracy: 0.5929 - val_loss: 1.7008 - val_weighted_accuracy: 0.5929
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6772 - loss: 1.1105 - weighted_accuracy: 0.6772 - val_accuracy: 0.6305 - val_loss: 1.5223 - val_weighted_accuracy: 0.6305
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6881 - loss: 1.0995 - weighted_accuracy: 0.6881 - val_accuracy: 0.6193 - val_loss: 1.6079 - val_weighted_accuracy: 0.6193
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6836 - loss: 1.1864 - weighted_accuracy: 0.6836 - val_accuracy: 0.5909 - val_loss: 1.7495 - val_weighted_accuracy: 0.5909
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6694 - loss: 1.1813 - weighted_accuracy: 0.6694 - val_accuracy: 0.6315 - val_loss: 1.5795 - val_weighted_accuracy: 0.6315
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6782 - loss: 1.1463 - weighted_accuracy: 0.6782 - val_accuracy: 0.5858 - val_loss: 1.5863 - val_weighted_accuracy: 0.5858
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6896 - loss: 1.1537 - weighted_accuracy: 0.6896 - val_accuracy: 0.6213 - val_loss: 1.5263 - val_weighted_accuracy: 0.6213

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['all_features'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['all_features'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6794 - loss: 1.0565 - weighted_accuracy: 0.6794
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5883 - loss: 1.5286 - weighted_accuracy: 0.5883

# %% [markdown]
# ## **With Mel-Spectrogram, MFCCs, Chroma**

# %%
training_features = np.concatenate((train_features['melspectrogram'], train_features['mfcc'], train_features['chroma']), axis=1)

print(training_features.shape)
# Out:
# (3954, 92, 259)

# %%
validation_features = np.concatenate((val_features['melspectrogram'], val_features['mfcc'], val_features['chroma']), axis=1)

print(validation_features.shape)
# Out:
# (985, 92, 259)

# %%
model = build_model(training_features)

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    start_from_epoch=50
)

history = model.fit(
    x=training_features,
    y=train_y,
    epochs=100,
    validation_data=(
        validation_features,
        val_y,
    ),
    batch_size=32,
    verbose=1,
    callbacks=[callback]
)

# best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))+1
# print('best_epoch: ', best_epoch)
visualize(history)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 256)                 │         397,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │             660 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 452,276 (1.73 MB)
#  Trainable params: 451,764 (1.72 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0672 - loss: 8.2405 - weighted_accuracy: 0.0672 - val_accuracy: 0.0619 - val_loss: 6.5775 - val_weighted_accuracy: 0.0619
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1104 - loss: 6.1739 - weighted_accuracy: 0.1104 - val_accuracy: 0.2294 - val_loss: 5.0552 - val_weighted_accuracy: 0.2294
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1638 - loss: 4.7319 - weighted_accuracy: 0.1638 - val_accuracy: 0.1107 - val_loss: 4.0720 - val_weighted_accuracy: 0.1107
# Epoch 4/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1886 - loss: 3.8075 - weighted_accuracy: 0.1886 - val_accuracy: 0.2183 - val_loss: 3.3743 - val_weighted_accuracy: 0.2183
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2043 - loss: 3.2035 - weighted_accuracy: 0.2043 - val_accuracy: 0.2579 - val_loss: 2.9385 - val_weighted_accuracy: 0.2579
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2703 - loss: 2.8008 - weighted_accuracy: 0.2703 - val_accuracy: 0.3137 - val_loss: 2.6615 - val_weighted_accuracy: 0.3137
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2823 - loss: 2.5751 - weighted_accuracy: 0.2823 - val_accuracy: 0.3442 - val_loss: 2.3893 - val_weighted_accuracy: 0.3442
# Epoch 8/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3117 - loss: 2.4194 - weighted_accuracy: 0.3117 - val_accuracy: 0.3046 - val_loss: 2.3176 - val_weighted_accuracy: 0.3046
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3281 - loss: 2.2500 - weighted_accuracy: 0.3281 - val_accuracy: 0.3838 - val_loss: 2.1731 - val_weighted_accuracy: 0.3838
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3750 - loss: 2.1686 - weighted_accuracy: 0.3750 - val_accuracy: 0.2832 - val_loss: 2.3058 - val_weighted_accuracy: 0.2832
# Epoch 11/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3966 - loss: 2.0694 - weighted_accuracy: 0.3966 - val_accuracy: 0.3350 - val_loss: 2.3091 - val_weighted_accuracy: 0.3350
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3939 - loss: 2.0226 - weighted_accuracy: 0.3939 - val_accuracy: 0.4365 - val_loss: 1.9564 - val_weighted_accuracy: 0.4365
# Epoch 13/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4132 - loss: 1.9379 - weighted_accuracy: 0.4132 - val_accuracy: 0.2569 - val_loss: 2.6634 - val_weighted_accuracy: 0.2569
# Epoch 14/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4126 - loss: 1.8912 - weighted_accuracy: 0.4126 - val_accuracy: 0.4365 - val_loss: 1.8823 - val_weighted_accuracy: 0.4365
# Epoch 15/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4513 - loss: 1.8333 - weighted_accuracy: 0.4513 - val_accuracy: 0.4254 - val_loss: 1.8798 - val_weighted_accuracy: 0.4254
# Epoch 16/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4511 - loss: 1.7928 - weighted_accuracy: 0.4511 - val_accuracy: 0.4487 - val_loss: 1.8016 - val_weighted_accuracy: 0.4487
# Epoch 17/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4607 - loss: 1.7499 - weighted_accuracy: 0.4607 - val_accuracy: 0.3563 - val_loss: 1.8504 - val_weighted_accuracy: 0.3563
# Epoch 18/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4841 - loss: 1.6847 - weighted_accuracy: 0.4841 - val_accuracy: 0.4629 - val_loss: 1.9092 - val_weighted_accuracy: 0.4629
# Epoch 19/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4871 - loss: 1.6636 - weighted_accuracy: 0.4871 - val_accuracy: 0.4386 - val_loss: 1.8983 - val_weighted_accuracy: 0.4386
# Epoch 20/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4741 - loss: 1.7330 - weighted_accuracy: 0.4741 - val_accuracy: 0.4152 - val_loss: 1.7390 - val_weighted_accuracy: 0.4152
# Epoch 21/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5024 - loss: 1.6665 - weighted_accuracy: 0.5024 - val_accuracy: 0.4843 - val_loss: 1.8328 - val_weighted_accuracy: 0.4843
# Epoch 22/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5072 - loss: 1.6033 - weighted_accuracy: 0.5072 - val_accuracy: 0.4711 - val_loss: 1.7467 - val_weighted_accuracy: 0.4711
# Epoch 23/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5233 - loss: 1.5963 - weighted_accuracy: 0.5233 - val_accuracy: 0.4355 - val_loss: 1.9563 - val_weighted_accuracy: 0.4355
# Epoch 24/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5160 - loss: 1.6037 - weighted_accuracy: 0.5160 - val_accuracy: 0.5015 - val_loss: 1.7408 - val_weighted_accuracy: 0.5015
# Epoch 25/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5414 - loss: 1.5207 - weighted_accuracy: 0.5414 - val_accuracy: 0.5310 - val_loss: 1.8499 - val_weighted_accuracy: 0.5310
# Epoch 26/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5468 - loss: 1.5237 - weighted_accuracy: 0.5468 - val_accuracy: 0.5239 - val_loss: 1.7380 - val_weighted_accuracy: 0.5239
# Epoch 27/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5485 - loss: 1.4448 - weighted_accuracy: 0.5485 - val_accuracy: 0.5431 - val_loss: 1.6528 - val_weighted_accuracy: 0.5431
# Epoch 28/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5710 - loss: 1.4801 - weighted_accuracy: 0.5710 - val_accuracy: 0.4853 - val_loss: 1.8050 - val_weighted_accuracy: 0.4853
# Epoch 29/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5564 - loss: 1.4802 - weighted_accuracy: 0.5564 - val_accuracy: 0.5340 - val_loss: 1.6646 - val_weighted_accuracy: 0.5340
# Epoch 30/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5885 - loss: 1.4395 - weighted_accuracy: 0.5885 - val_accuracy: 0.4325 - val_loss: 1.8877 - val_weighted_accuracy: 0.4325
# Epoch 31/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5538 - loss: 1.4992 - weighted_accuracy: 0.5538 - val_accuracy: 0.4528 - val_loss: 2.0607 - val_weighted_accuracy: 0.4528
# Epoch 32/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5748 - loss: 1.4478 - weighted_accuracy: 0.5748 - val_accuracy: 0.4548 - val_loss: 1.8976 - val_weighted_accuracy: 0.4548
# Epoch 33/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5683 - loss: 1.4567 - weighted_accuracy: 0.5683 - val_accuracy: 0.5371 - val_loss: 1.6535 - val_weighted_accuracy: 0.5371
# Epoch 34/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5959 - loss: 1.3864 - weighted_accuracy: 0.5959 - val_accuracy: 0.5056 - val_loss: 1.6540 - val_weighted_accuracy: 0.5056
# Epoch 35/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6120 - loss: 1.3444 - weighted_accuracy: 0.6120 - val_accuracy: 0.5746 - val_loss: 1.7059 - val_weighted_accuracy: 0.5746
# Epoch 36/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6011 - loss: 1.3523 - weighted_accuracy: 0.6011 - val_accuracy: 0.5513 - val_loss: 1.6391 - val_weighted_accuracy: 0.5513
# Epoch 37/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5952 - loss: 1.3338 - weighted_accuracy: 0.5952 - val_accuracy: 0.5584 - val_loss: 1.5427 - val_weighted_accuracy: 0.5584
# Epoch 38/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6097 - loss: 1.3813 - weighted_accuracy: 0.6097 - val_accuracy: 0.5208 - val_loss: 1.8812 - val_weighted_accuracy: 0.5208
# Epoch 39/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6087 - loss: 1.3318 - weighted_accuracy: 0.6087 - val_accuracy: 0.5736 - val_loss: 1.5863 - val_weighted_accuracy: 0.5736
# Epoch 40/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6286 - loss: 1.2744 - weighted_accuracy: 0.6286 - val_accuracy: 0.5838 - val_loss: 1.6557 - val_weighted_accuracy: 0.5838
# Epoch 41/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6086 - loss: 1.3067 - weighted_accuracy: 0.6086 - val_accuracy: 0.5046 - val_loss: 1.5535 - val_weighted_accuracy: 0.5046
# Epoch 42/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6208 - loss: 1.2948 - weighted_accuracy: 0.6208 - val_accuracy: 0.5980 - val_loss: 1.5411 - val_weighted_accuracy: 0.5980
# Epoch 43/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6321 - loss: 1.2516 - weighted_accuracy: 0.6321 - val_accuracy: 0.5827 - val_loss: 1.5616 - val_weighted_accuracy: 0.5827
# Epoch 44/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6181 - loss: 1.3271 - weighted_accuracy: 0.6181 - val_accuracy: 0.4975 - val_loss: 1.6377 - val_weighted_accuracy: 0.4975
# Epoch 45/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6340 - loss: 1.2771 - weighted_accuracy: 0.6340 - val_accuracy: 0.5665 - val_loss: 1.7012 - val_weighted_accuracy: 0.5665
# Epoch 46/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6221 - loss: 1.2759 - weighted_accuracy: 0.6221 - val_accuracy: 0.4914 - val_loss: 1.7347 - val_weighted_accuracy: 0.4914
# Epoch 47/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6413 - loss: 1.2163 - weighted_accuracy: 0.6413 - val_accuracy: 0.5655 - val_loss: 1.5791 - val_weighted_accuracy: 0.5655
# Epoch 48/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6664 - loss: 1.1520 - weighted_accuracy: 0.6664 - val_accuracy: 0.5888 - val_loss: 1.5565 - val_weighted_accuracy: 0.5888
# Epoch 49/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6351 - loss: 1.2291 - weighted_accuracy: 0.6351 - val_accuracy: 0.5777 - val_loss: 1.8269 - val_weighted_accuracy: 0.5777
# Epoch 50/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6474 - loss: 1.2076 - weighted_accuracy: 0.6474 - val_accuracy: 0.6081 - val_loss: 1.6079 - val_weighted_accuracy: 0.6081
# Epoch 51/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6625 - loss: 1.1794 - weighted_accuracy: 0.6625 - val_accuracy: 0.5919 - val_loss: 1.6363 - val_weighted_accuracy: 0.5919
# Epoch 52/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6423 - loss: 1.1856 - weighted_accuracy: 0.6423 - val_accuracy: 0.5431 - val_loss: 1.5466 - val_weighted_accuracy: 0.5431
# Epoch 53/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6481 - loss: 1.1774 - weighted_accuracy: 0.6481 - val_accuracy: 0.5279 - val_loss: 1.8950 - val_weighted_accuracy: 0.5279
# Epoch 54/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6484 - loss: 1.1639 - weighted_accuracy: 0.6484 - val_accuracy: 0.4701 - val_loss: 2.5079 - val_weighted_accuracy: 0.4701
# Epoch 55/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6297 - loss: 1.2610 - weighted_accuracy: 0.6297 - val_accuracy: 0.5381 - val_loss: 1.6298 - val_weighted_accuracy: 0.5381
# Epoch 56/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6663 - loss: 1.1682 - weighted_accuracy: 0.6663 - val_accuracy: 0.5239 - val_loss: 1.6948 - val_weighted_accuracy: 0.5239
# Epoch 57/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6614 - loss: 1.1677 - weighted_accuracy: 0.6614 - val_accuracy: 0.4589 - val_loss: 2.3998 - val_weighted_accuracy: 0.4589
# Epoch 58/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6392 - loss: 1.1963 - weighted_accuracy: 0.6392 - val_accuracy: 0.6213 - val_loss: 1.6547 - val_weighted_accuracy: 0.6213
# Epoch 59/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6620 - loss: 1.1331 - weighted_accuracy: 0.6620 - val_accuracy: 0.5970 - val_loss: 1.6057 - val_weighted_accuracy: 0.5970
# Epoch 60/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6707 - loss: 1.1353 - weighted_accuracy: 0.6707 - val_accuracy: 0.5898 - val_loss: 1.6985 - val_weighted_accuracy: 0.5898
# Epoch 61/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6859 - loss: 1.1047 - weighted_accuracy: 0.6859 - val_accuracy: 0.5147 - val_loss: 1.5895 - val_weighted_accuracy: 0.5147
# Epoch 62/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6566 - loss: 1.1943 - weighted_accuracy: 0.6566 - val_accuracy: 0.5939 - val_loss: 1.7595 - val_weighted_accuracy: 0.5939
# Epoch 63/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6839 - loss: 1.0768 - weighted_accuracy: 0.6839 - val_accuracy: 0.5787 - val_loss: 1.9120 - val_weighted_accuracy: 0.5787
# Epoch 64/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6769 - loss: 1.1488 - weighted_accuracy: 0.6769 - val_accuracy: 0.5746 - val_loss: 1.7005 - val_weighted_accuracy: 0.5746
# Epoch 65/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6689 - loss: 1.1072 - weighted_accuracy: 0.6689 - val_accuracy: 0.6213 - val_loss: 1.6354 - val_weighted_accuracy: 0.6213
# Epoch 66/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6802 - loss: 1.0829 - weighted_accuracy: 0.6802 - val_accuracy: 0.6234 - val_loss: 1.6720 - val_weighted_accuracy: 0.6234
# Epoch 67/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6762 - loss: 1.0824 - weighted_accuracy: 0.6762 - val_accuracy: 0.6234 - val_loss: 1.7152 - val_weighted_accuracy: 0.6234
# Epoch 68/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6836 - loss: 1.0600 - weighted_accuracy: 0.6836 - val_accuracy: 0.6102 - val_loss: 1.5888 - val_weighted_accuracy: 0.6102
# Epoch 69/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6954 - loss: 1.0612 - weighted_accuracy: 0.6954 - val_accuracy: 0.5228 - val_loss: 1.8062 - val_weighted_accuracy: 0.5228
# Epoch 70/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6824 - loss: 1.0609 - weighted_accuracy: 0.6824 - val_accuracy: 0.6213 - val_loss: 1.6717 - val_weighted_accuracy: 0.6213
# Epoch 71/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6960 - loss: 1.0287 - weighted_accuracy: 0.6960 - val_accuracy: 0.6406 - val_loss: 1.6281 - val_weighted_accuracy: 0.6406
# Epoch 72/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6948 - loss: 0.9975 - weighted_accuracy: 0.6948 - val_accuracy: 0.5787 - val_loss: 1.6365 - val_weighted_accuracy: 0.5787

# %%
train_yhat = model.predict(training_features)
train_yhat_result = np.argmax(train_yhat, axis=-1)
train_results['melspectrogram_chroma_mfcc'] = model.evaluate(training_features, train_y)[-1]

val_yhat = model.predict(validation_features)
val_yhat_result = np.argmax(val_yhat, axis=-1)
val_results['melspectrogram_chroma_mfcc'] = model.evaluate(validation_features, val_y)[-1]
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6939 - loss: 1.0105 - weighted_accuracy: 0.6939
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5228 - loss: 1.6586 - weighted_accuracy: 0.5228

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(3)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(3)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Features')
result_df
# Out:
#                      Features  Train_Accuracy  Val_Accuracy
# 0                all_features           0.689         0.608
# 1  melspectrogram_chroma_mfcc           0.701         0.543
